# %%
from transformers import AutoTokenizer, BartForConditionalGeneration, T5ForConditionalGeneration, AdamW
from torch.utils.data import Dataset, DataLoader
import torch
import json
import transformers

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def read_data(file_path):
    data = []
    with open(file_path, 'r') as fd:
        json_list = list(fd)

        for json_str in json_list:
            result = json.loads(json_str)
            data.append(result)
    return data

# %%
train_set = read_data('/kaggle/input/dialogue-system/train.jsonl')
dev_set = read_data('/kaggle/input/dialogue-system/dev.jsonl')

# %%
dev_set[0]
# Out:
# {'input': 'Email my my dad with directions to the to the wedding.',
#  'history': [{'user_query': 'create a list name Garage Sale',
#    'response_text': 'Sorry, it looks like you already have a list with that name. Do you still want to make a new one?'},
#   {'user_query': 'add organize stuff and prepare flyers ',
#    'response_text': 'OK, what do you want to call it?'},
#   {'user_query': 'Garage Sale',
#    'response_text': 'Sure, I made a list called "Garage Sale" and added those two things.'}],
#  'user_lists': [{'name': 'Good Girl Names', 'items': ['Autumn', 'Summer']},
#   {'name': 'fruit salad', 'items': ['strawberries']}],
#  'user_notes': [{'name': "don't forget to pick up milk", 'content': ''},
#   {'name': 'pick up milk', 'content': ''}],
#  'user_contacts': ['Dad ',
#   'my dad',
#   'Dad',
#   'My Honey',
#   'James Keenan',
#   'Stacy Willis',
#   'Dr. Jerkins',
#   'Publix Bakery',
#   'Michelle',
#   'my office',
#   'Elizabeth',
#   'Laurie',
#   'Vet'],
#  'output': 'Send_digital_object ( medium « Email » object Electronic_message ( content « directions to the to the wedding » ) recipient Personal_contact ( person « my dad » ) )'}

# %%
tokenizer = AutoTokenizer.from_pretrained("t5-small")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]

# %%
def process_data(data):
    data_x, data_y = [], []
    for sample in data:
        data_x.append(sample['input'])
        data_y.append(sample['output'])
    return list(zip(data_x, data_y))

train = process_data(train_set)
dev = process_data(dev_set)

# %%
def collate(batch):
    X, Y = zip(*batch)
    X = tokenizer(X, padding = True, return_tensors = 'pt')
    Y = tokenizer(Y, padding = True, return_tensors = 'pt')
    length = len(Y['input_ids'])
    Y['input_ids'][Y['input_ids']==0] = -100
    return X, Y

# %%
EPOCHS = 15
PATIENCE = 20
BATCH_SIZE = 64
train_loader = DataLoader(train, batch_size = BATCH_SIZE, shuffle = True, collate_fn=collate)
dev_loader = DataLoader(dev, batch_size = BATCH_SIZE, collate_fn=collate)

# %%
a = next(iter(train_loader))

# %%
tokenizer.pad_token_id
# Out:
# 0

# %%
model = T5ForConditionalGeneration.from_pretrained("t5-small").to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=2e-4)
lr_scheduler = transformers.get_scheduler(name="linear", optimizer=optimizer, num_warmup_steps=0, num_training_steps=(EPOCHS+10)*len(train_loader))
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/242M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
def train_model(train_loader, model):
    step_check = 50
    step_count = 0
    counter = 0
    val_best = float('inf')
    val_best_acc = -float('inf')
    running_loss = 0.0
    for epoch in range(EPOCHS):
        print(f'Epoch {epoch+1}:')
        print('-'*20)
        for batch, (X,Y) in enumerate(train_loader):
            model.train()
            optimizer.zero_grad()
            
            input_ids = X['input_ids'].to(device)
            attention_mask = X['attention_mask'].to(device)
            decoder_input_ids = Y['input_ids'].to(device)
            outputs = model(input_ids, attention_mask, labels=decoder_input_ids)
            loss = outputs.loss
            running_loss += loss.item()
            loss.backward()
            optimizer.step()
            lr_scheduler.step()
            
            step_count+=1
            if step_count==step_check:
                print(f'Train_loss: {(running_loss/step_count):>5f}')
                val_loss = val_loop(dev_loader, model)
                if val_loss < val_best:
                    print(f'Val loss decreased: {val_best:7f} ----> {val_loss:7f}')
                    val_best = val_loss
                    torch.save(model.state_dict(), '/kaggle/working/aib222684_model')
                    counter=0
                else:
                    counter+=1
                if counter == PATIENCE:
                    break
                step_count = 0
                running_loss = 0.0
        if counter == PATIENCE:
            break
        val_acc = val_accuracy(dev_loader, model, dev_set)
        print(f'Validation accuracy: {val_acc:7f}')
        if val_acc > val_best_acc:
            val_best_acc = val_acc
            torch.save(model.state_dict(), '/kaggle/working/t5-acc.pth')

# %%
def val_accuracy(dev_loader, model, dev_set):
    model.eval()
    idx = 0
    acc = 0
    with torch.no_grad():
        for (X, _) in dev_loader:
            input_ids  = X["input_ids"].to(device)
            results = model.generate(input_ids, num_beams=3, min_length=0, max_length=150)
            results = tokenizer.batch_decode(results, skip_special_tokens=True, clean_up_tokenization_spaces=False)
            for result in results:
                if result==dev_set[idx]['output']: acc+=1
                idx+=1
    return acc/len(dev_set)

# %%
def val_loop(dataloader, model):
    size = len(dataloader)
    cost = 0.0
    model.eval()
    for X,Y in dataloader:
        input_ids = X['input_ids'].to(device)
        attention_mask = X['attention_mask'].to(device)
        decoder_input_ids =  Y['input_ids'].to(device)
        output = model(input_ids, attention_mask, labels = decoder_input_ids)
        cost += output.loss.item()
    return cost/size

# %%
train_model(train_loader, model)
# Out:
# Epoch 1:
# --------------------
# Train_loss: 3.171859
# Val loss decreased:     inf ----> 1.397334
# Train_loss: 1.415407
# Val loss decreased: 1.397334 ----> 0.636142
# Train_loss: 0.922962
# Val loss decreased: 0.636142 ----> 0.431073
# Train_loss: 0.693979
# Val loss decreased: 0.431073 ----> 0.324726
# Train_loss: 0.553870
# Val loss decreased: 0.324726 ----> 0.263594
# Train_loss: 0.477244
# Val loss decreased: 0.263594 ----> 0.222820
# Train_loss: 0.407483
# Val loss decreased: 0.222820 ----> 0.196596
# Train_loss: 0.356708
# Val loss decreased: 0.196596 ----> 0.166489
# Train_loss: 0.324005
# Val loss decreased: 0.166489 ----> 0.146739
# Validation accuracy: 0.570643
# Epoch 2:
# --------------------
# Train_loss: 0.288944
# Val loss decreased: 0.146739 ----> 0.134109
# Train_loss: 0.260854
# Val loss decreased: 0.134109 ----> 0.125554
# Train_loss: 0.249552
# Val loss decreased: 0.125554 ----> 0.116227
# Train_loss: 0.234483
# Val loss decreased: 0.116227 ----> 0.108967
# Train_loss: 0.221432
# Val loss decreased: 0.108967 ----> 0.098709
# Train_loss: 0.214303
# Val loss decreased: 0.098709 ----> 0.093890
# Train_loss: 0.197399
# Val loss decreased: 0.093890 ----> 0.090086
# Train_loss: 0.187487
# Val loss decreased: 0.090086 ----> 0.085149
# Train_loss: 0.175488
# Val loss decreased: 0.085149 ----> 0.083556
# Train_loss: 0.177351
# Val loss decreased: 0.083556 ----> 0.079822
# Validation accuracy: 0.702222
# Epoch 3:
# --------------------
# Train_loss: 0.163818
# Val loss decreased: 0.079822 ----> 0.078356
# Train_loss: 0.155584
# Val loss decreased: 0.078356 ----> 0.073056
# Train_loss: 0.148637
# Train_loss: 0.144875
# Val loss decreased: 0.073056 ----> 0.072285
# Train_loss: 0.140406
# Val loss decreased: 0.072285 ----> 0.068261
# Train_loss: 0.137061
# Val loss decreased: 0.068261 ----> 0.068232
# Train_loss: 0.129792
# Val loss decreased: 0.068232 ----> 0.064818
# Train_loss: 0.126525
# Val loss decreased: 0.064818 ----> 0.064363
# Train_loss: 0.127734
# Val loss decreased: 0.064363 ----> 0.062736
# Train_loss: 0.124472
# Val loss decreased: 0.062736 ----> 0.062006
# Validation accuracy: 0.762511
# Epoch 4:
# --------------------
# Train_loss: 0.115723
# Train_loss: 0.107110
# Val loss decreased: 0.062006 ----> 0.059835
# Train_loss: 0.107446
# Val loss decreased: 0.059835 ----> 0.058795
# Train_loss: 0.109804
# Val loss decreased: 0.058795 ----> 0.058175
# Train_loss: 0.106193
# Val loss decreased: 0.058175 ----> 0.055947
# Train_loss: 0.100053
# Val loss decreased: 0.055947 ----> 0.055382
# Train_loss: 0.103318
# Val loss decreased: 0.055382 ----> 0.054168
# Train_loss: 0.100841
# Val loss decreased: 0.054168 ----> 0.053392
# Train_loss: 0.101910
# Validation accuracy: 0.794651
# Epoch 5:
# --------------------
# Train_loss: 0.095192
# Train_loss: 0.088897
# Val loss decreased: 0.053392 ----> 0.052019
# Train_loss: 0.089247
# Val loss decreased: 0.052019 ----> 0.051576
# Train_loss: 0.090514
# Val loss decreased: 0.051576 ----> 0.051197
# Train_loss: 0.085781
# Val loss decreased: 0.051197 ----> 0.050608
# Train_loss: 0.087824
# Val loss decreased: 0.050608 ----> 0.049220
# Train_loss: 0.088355
# Train_loss: 0.083958
# Val loss decreased: 0.049220 ----> 0.048483
# Train_loss: 0.082197
# Val loss decreased: 0.048483 ----> 0.047865
# Train_loss: 0.077065
# Validation accuracy: 0.810720
# Epoch 6:
# --------------------
# Train_loss: 0.073663
# Val loss decreased: 0.047865 ----> 0.047416
# Train_loss: 0.070500
# Train_loss: 0.072575
# Train_loss: 0.075309
# Train_loss: 0.073925
# Val loss decreased: 0.047416 ----> 0.047197
# Train_loss: 0.077465
# Train_loss: 0.069262
# Val loss decreased: 0.047197 ----> 0.046056
# Train_loss: 0.072011
# Val loss decreased: 0.046056 ----> 0.044971
# Train_loss: 0.068330
# Train_loss: 0.068634
# Validation accuracy: 0.821182
# Epoch 7:
# --------------------
# Train_loss: 0.065646
# Train_loss: 0.064763
# Train_loss: 0.064457
# Val loss decreased: 0.044971 ----> 0.044306
# Train_loss: 0.066873
# Val loss decreased: 0.044306 ----> 0.043757
# Train_loss: 0.064609
# Train_loss: 0.060311
# Train_loss: 0.066780
# Val loss decreased: 0.043757 ----> 0.043646
# Train_loss: 0.062277
# Train_loss: 0.058113
# Validation accuracy: 0.827761
# Epoch 8:
# --------------------
# Train_loss: 0.061731
# Val loss decreased: 0.043646 ----> 0.043340
# Train_loss: 0.055380
# Train_loss: 0.058685
# Train_loss: 0.055205
# Val loss decreased: 0.043340 ----> 0.042832
# Train_loss: 0.053597
# Train_loss: 0.062289
# Train_loss: 0.054349
# Val loss decreased: 0.042832 ----> 0.042317
# Train_loss: 0.052984
# Train_loss: 0.058493
# Val loss decreased: 0.042317 ----> 0.041993
# Train_loss: 0.052479
# Val loss decreased: 0.041993 ----> 0.040954
# Validation accuracy: 0.833046
# Epoch 9:
# --------------------
# Train_loss: 0.052075
# Train_loss: 0.049306
# Train_loss: 0.050181
# Train_loss: 0.048737
# Train_loss: 0.050534
# Train_loss: 0.051857
# Val loss decreased: 0.040954 ----> 0.040939
# Train_loss: 0.048111
# Train_loss: 0.045952
# Train_loss: 0.049907
# Train_loss: 0.049444
# Validation accuracy: 0.842321
# Epoch 10:
# --------------------
# Train_loss: 0.046913
# Train_loss: 0.044150
# Train_loss: 0.050512
# Val loss decreased: 0.040939 ----> 0.039877
# Train_loss: 0.046845
# Train_loss: 0.048310
# Train_loss: 0.045144
# Train_loss: 0.043654
# Train_loss: 0.046762
# Train_loss: 0.043842
# Train_loss: 0.044877
# Validation accuracy: 0.846635
# Epoch 11:
# --------------------
# Train_loss: 0.041572
# Val loss decreased: 0.039877 ----> 0.039638
# Train_loss: 0.040924
# Train_loss: 0.042158
# Train_loss: 0.039825
# Train_loss: 0.043253
# Train_loss: 0.038585
# Train_loss: 0.038353
# Train_loss: 0.047095
# Train_loss: 0.040480
# Val loss decreased: 0.039638 ----> 0.039579
# Validation accuracy: 0.850410
# Epoch 12:
# --------------------
# Train_loss: 0.039827
# Train_loss: 0.037671
# Train_loss: 0.039295
# Train_loss: 0.039922
# Train_loss: 0.037458
# Train_loss: 0.041787
# Train_loss: 0.039679
# Val loss decreased: 0.039579 ----> 0.039122
# Train_loss: 0.035068
# Val loss decreased: 0.039122 ----> 0.038689
# Train_loss: 0.039690
# Train_loss: 0.038454
# Validation accuracy: 0.845125
# Epoch 13:
# --------------------
# Train_loss: 0.040085
# Train_loss: 0.038356
# Train_loss: 0.034318
# Train_loss: 0.035259
# Train_loss: 0.034127
# Train_loss: 0.036452
# Train_loss: 0.037962
# Val loss decreased: 0.038689 ----> 0.038543
# Train_loss: 0.035580
# Train_loss: 0.033968
# Train_loss: 0.035664
# Validation accuracy: 0.854508
# Epoch 14:
# --------------------
# Train_loss: 0.031214
# Train_loss: 0.034007
# Train_loss: 0.031260
# Train_loss: 0.034635
# Train_loss: 0.032535
# Train_loss: 0.031428
# Train_loss: 0.032836
# Train_loss: 0.038856
# Train_loss: 0.031685
# Validation accuracy: 0.853969
# Epoch 15:
# --------------------
# Train_loss: 0.034023
# Train_loss: 0.028359
# Train_loss: 0.034386
# Train_loss: 0.033560
# Train_loss: 0.032898
# Train_loss: 0.029212
# Train_loss: 0.033609
# Train_loss: 0.032780

# %%
X, Y = next(iter(dev_loader))
model_test = T5ForConditionalGeneration.from_pretrained("t5-small").to(device)
model_test.load_state_dict(torch.load('/kaggle/working/aib222684_model'))
# Out:
# <All keys matched successfully>

# %%
input_ids  = X["input_ids"].to(device)
result = model_test.generate(input_ids, num_beams=5, min_length=0, max_length=100)

# %%
tokenizer.batch_decode(result, skip_special_tokens=True, clean_up_tokenization_spaces=False)
# Out:
# ['Send_digital_object ( medium « Email » object Electronic_message ( content « directions to the wedding » ) recipient Personal_contact ( person « my dad » ) )',
#  'Send_digital_object ( format « video » recipient Personal_contact ( person « John » ) )',
#  'Send_digital_object ( medium « text message » recipient Personal_contact ( person « Lauren » ) )',
#  'Send_digital_object ( cc Personal_contact ( person « John » ) medium « Email » recipient Personal_contact ( person « Troy » ) )',
#  'Send_digital_object ( medium « message » provider « Snapchat » )',
#  'Send_digital_object ( medium « message » recipient Organization_contact ( organization « Fundido » ) )',
#  'Send_digital_object ( attachment « ETA » medium « text » recipient Contactable_entity ( contact_id Phone_number ( id_form « 384-384-3948 » ) ) )',
#  'Send_digital_object ( medium « text message » recipient Personal_contact ( person « Zander » ) )',
#  'Send_digital_object ( medium « email » recipient Personal_contact ( person « Meliza » ) )',
#  'Send_digital_object ( medium « text » recipient Personal_contact ( person « Jack » ) )',
#  'Send_digital_object ( format « voice » medium « memo » recipient Personal_contact ( label « mobile » person « Daniel » ) )',
#  'Send_digital_object ( medium « text » recipient Personal_contact ( label « home » person « George » ) )',
#  'Send_digital_object ( attachment « photo » recipient Personal_contact ( label « work » person « John » ) )',
#  'Send_digital_object ( medium « email » recipient Contactable_entity ( contact_id Email_address ( id_form « Yesmygame@aol.com » ) ) )',
#  'Send_digital_object ( medium « email » recipient Personal_contact ( person « Joe » ) )',
#  'Get_message_content ( message Electronic_message ( medium « email » ) )',
#  'Send_digital_object ( medium « email » recipient Personal_contact ( person « Nick » ) )',
#  'Send_digital_object ( medium « Text » object Electronic_message ( content « location » ) recipient Personal_contact ( person « mom » ) )',
#  'Send_digital_object ( medium « email » recipient Personal_contact ( person « Rhett » ) recipient Contactable_entity ( contact_id Email_address ( id_form « rhett@gmail.com » ) ) )',
#  'Send_digital_object ( medium « message » provider « WhatsApp » )',
#  'Send_digital_object ( medium « message » provider « instagram » recipient Personal_contact ( person « ashleigh » ) )',
#  'Send_digital_object ( bcc Personal_contact ( person « Mr. Jones » ) medium « Email » object Electronic_message ( content « the itinerary » ) recipient Personal_contact ( person « Mr. Smith » ) )',
#  'Send_digital_object ( attachment « ETA » provider « Facebook » )',
#  'Send_digital_object ( medium « email » recipient Personal_contact ( person « Seth Melton » ) )',
#  'Send_digital_object ( attachment « screenshot » recipient Contactable_entity ( contact_id Email_address ( id_form « samh@hut.com » ) ) )',
#  'Send_digital_object ( medium « text » recipient Personal_contact ( person « Ernesto » ) )',
#  'Send_digital_object ( attachment « location » provider « Snapchat » recipient Personal_contact ( person « Sam » ) )',
#  'Send_digital_object ( medium « Email » recipient Personal_contact ( person « Kimberly » ) recipient Contactable_entity ( contact_id Phone_number ( id_form « 372-372-8463 » ) ) )',
#  'Send_digital_object ( medium « text » )',
#  'Send_digital_object ( format « video » medium « message » recipient Personal_contact ( person « Zach » ) )',
#  'Send_digital_object ( medium « email » recipient Personal_contact ( person « Jen » ) )',
#  'Send_digital_object ( medium « Email » object Electronic_message ( content « hello » ) recipient Personal_contact ( person « Paul » ) )',
#  'Send_digital_object ( object « ETA » provider « skype » )',
#  'Send_digital_object ( medium « email » object Electronic_message ( content « a work » ) recipient Personal_contact ( person « Joan Hagerty » ) )',
#  'Send_digital_object ( medium « text » recipient Contactable_entity ( contact_id Phone_number ( id_form « 445 664 2314 » ) ) )',
#  'Send_digital_object ( medium « email » recipient Personal_contact ( person « Rhett » ) )',
#  'Send_digital_object ( format « video » medium « message » provider « FaceTime » recipient Personal_contact ( person « Tom » ) )',
#  "Send_digital_object ( medium « text » object Electronic_message ( content « we'll take the house » ) recipient Personal_contact ( person « Mr. Smith » ) )",
#  'Send_digital_object ( medium « Email » recipient Personal_contact ( person « Katie » ) )',
#  'Send_digital_object ( bcc Personal_contact ( person « Sarah » ) medium « Email » recipient Personal_contact ( person « Mom » ) )',
#  'Send_digital_object ( medium « email » recipient Personal_contact ( person « Mom » ) )',
#  'Send_digital_object ( medium « message » provider « WhatsApp » recipient Personal_contact ( person « Sara » ) )',
#  'Send_digital_object ( format « audio » medium « message » provider « WhatsApp » recipient Personal_contact ( person « Jill » ) )',
#  'Send_digital_object ( medium « email » )',
#  'Send_digital_object ( medium « email » recipient Organization_contact ( organization « Ave » ) )',
#  'Send_digital_object ( medium « Skype » recipient Personal_contact ( person « Tim » ) )',
#  "Send_digital_object ( medium « email » object Electronic_message ( content « I'll be late » ) recipient Contactable_entity ( contact_id Email_address ( id_form « jane@gmail.com » ) ) )",
#  'Send_digital_object ( attachment « location » medium « text » )',
#  'Send_digital_object ( format « voice » medium « message » recipient Personal_contact ( person « Stan » ) )',
#  'Send_digital_object ( medium « text » recipient Personal_contact ( person « Paul » ) )',
#  'Send_digital_object ( attachment « Eta » provider « Snapchat » recipient Personal_contact ( person « Karen » ) )',
#  'Send_digital_object ( medium « message » recipient Personal_contact ( person « Rita » ) )',
#  'Send_digital_object ( medium « Text » recipient Contactable_entity ( contact_id Phone_number ( id_form « 205-444-3323 » ) ) )',
#  'Send_digital_object ( medium « email » object Electronic_message ( topic « the cat » ) recipient Personal_contact ( person « Erin » ) )',
#  'Send_digital_object ( medium « text » recipient Personal_contact ( person « dad » ) )',
#  'Send_digital_object ( medium « Text » recipient Contactable_entity ( contact_id Phone_number ( id_form « 541-6565 » ) ) )',
#  'Send_digital_object ( medium « Email » object Electronic_message ( content « customer service » provider « Amazon » ) recipient Personal_contact ( person « Amazon » ) )',
#  'Send_digital_object ( attachment « location » recipient Personal_contact ( person « Jen » ) )',
#  'Send_digital_object ( medium « Text » recipient Contactable_entity ( contact_id Phone_number ( id_form « 777-777-777 » ) ) )',
#  'Send_digital_object ( medium « text » recipient Personal_contact ( person « my son » ) )',
#  'Send_digital_object ( medium « SMS » recipient Personal_contact ( person « Jonah » ) )',
#  'Send_digital_object ( format « audio » medium « message » object Electronic_message ( content « the show is uh cancelled » ) recipient Personal_contact ( person « Rhett » ) )',
#  'Send_digital_object ( attachment « ETA » medium « text » recipient Personal_contact ( person « CIndy » ) )',
#  'Send_digital_object ( medium « text » recipient Contactable_entity ( contact_id Phone_number ( id_form « 666-999-5555 » ) ) )']

# %%
def generate_file(fileName, dataloader, model):
    fd = open(fileName, 'w+')
    model.eval()
    for (X,_) in dataloader:
        input_ids  = X["input_ids"].to(device)
        results = model.generate(input_ids, num_beams=3, min_length=0, max_length=100)
        results = tokenizer.batch_decode(results, skip_special_tokens=True, clean_up_tokenization_spaces=False)
        for result in results:
            fd.write(result+'\n')
    fd.close()

# %%
generate_file('pred_file.txt', dev_loader, model_test)

# %%
tokenizer.pad_token_id
# Out:
# 0

# %%
val_accuracy(dev_loader, model, dev_set)
