# %%
import torch
import torch.nn as nn
import torch.backends.cudnn as cudnn
import torchvision
import torchvision.datasets as datasets
from torchvision.transforms import transforms
from torch.utils.data import DataLoader
from torch.utils.data import random_split
import torch.optim as optim
from torch.optim import Adam
import torch.nn as nn
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score
from torch.utils.data import Dataset
import torch.nn.functional as F
import joblib
import os
import random
from PIL import Image

# %%
def error_index(org_lables, error_ratio, num_classes):
    error = org_lables.copy()
    # determine the number of elements to update (10% of the list length)
    num_updates = int(len(org_lables) * error_ratio)

    update_indices = random.sample(range(len(org_lables)), num_updates)

    # subtract a random integer from each of the selected elements
    for idx in update_indices:
        error[idx] = random.sample([num for num in range(num_classes) if num != org_lables[idx]], 1)[0]
    return error


def csv_creator(root_dir, dataset_name):
    # define the class labels
    class_labels = os.listdir(root_dir)

    # create a dictionary to map class names to integers
    class_dict = {class_labels[i]: i for i in range(len(class_labels))}

    # create a list to store the image paths and class labels
    data = []

    # iterate over the class labels and their corresponding directories
    for label in class_labels:
        dir_path = os.path.join(root_dir, label)
        img_names = os.listdir(dir_path)
        # iterate over the image names and add their paths and class labels to the data list
        for img_name in img_names:
            img_path = os.path.join(dir_path, img_name)
            class_label = class_dict[label]
            data.append((img_path, class_label))
            
    random.shuffle(data)

    # calculate the split index for the train and test sets
    split_idx = int(0.8 * len(data))

    # create train and test dataframes
    train_df = pd.DataFrame(data[:split_idx], columns=['path', 'label'])
    test_df = pd.DataFrame(data[split_idx:], columns=['path', 'label'])

    org_lables = list(train_df['label'])
    num_classes = len(class_dict)
    
    
    error10 = error_index(org_lables, 0.1, num_classes)
    error20 = error_index(org_lables, 0.2, num_classes)
    error40 = error_index(org_lables, 0.4, num_classes)

    train_df = pd.DataFrame({'path':train_df['path'], 'lable':train_df['label'], 'error10':error10,
                             'error20':error20, 'error40':error40})


    # save the dataframes as CSV files
    train_df.to_csv(dataset_name+'train.csv', index=False)
    test_df.to_csv(dataset_name+'test.csv', index=False)

# %%
# specify the root directory for datasets
UCM_root_dir = '/kaggle/input/ucmerced/UCMerced_LandUse/Images'
Optimal31_root_dir = '/kaggle/input/optimal-31/OPTIMAL-31/Images'

UCM_classes = os.listdir(UCM_root_dir)
Optimal31_classes = os.listdir(Optimal31_root_dir)

csv_creator(UCM_root_dir, 'UCM_')
csv_creator(Optimal31_root_dir, 'Optimal31_')

# %%
# define a custom dataset class
class Dataset_creator(Dataset):
    def __init__(self, csv_file, col_indx = 1, transform=None):
        self.data = pd.read_csv(csv_file)
        self.col_indx = col_indx
        self.transform = transform
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        img_path = self.data.iloc[idx, 0]
        label = self.data.iloc[idx, self.col_indx]
        img = Image.open(img_path)
        if self.transform:
            img = self.transform(img)
        return img, label

#  Load and normalizing dataset
transforms_train = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

transforms_test = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# create UCMercedDataset objects for training and testing
UCM_trainDataset = Dataset_creator('/kaggle/working/UCM_train.csv', 1, transform=transforms_train)
UCM_trainDataset10 = Dataset_creator('/kaggle/working/UCM_train.csv', 2, transform=transforms_train)
UCM_trainDataset20 = Dataset_creator('/kaggle/working/UCM_train.csv', 3, transform=transforms_train)
UCM_trainDataset40 = Dataset_creator('/kaggle/working/UCM_train.csv', 4, transform=transforms_train)
UCM_testDataset = Dataset_creator('/kaggle/working/UCM_test.csv', transform=transforms_test)

# create DataLoader objects for training and testing
UCM_trainDatasetLoader = DataLoader(UCM_trainDataset, batch_size=32, shuffle=True)
UCM_trainDatasetLoader10 = DataLoader(UCM_trainDataset10, batch_size=32, shuffle=True)
UCM_trainDatasetLoader20 = DataLoader(UCM_trainDataset20, batch_size=32, shuffle=True)
UCM_trainDatasetLoader40= DataLoader(UCM_trainDataset40, batch_size=32, shuffle=True)
UCM_testDatasetLoader = DataLoader(UCM_testDataset, batch_size=32, shuffle=False)

# create Optimal31Dataset objects for training and testing
Optimal31_trainDataset = Dataset_creator('/kaggle/working/Optimal31_train.csv', 1, transform=transforms_train)
Optimal31_trainDataset10 = Dataset_creator('/kaggle/working/Optimal31_train.csv', 2, transform=transforms_train)
Optimal31_trainDataset20 = Dataset_creator('/kaggle/working/Optimal31_train.csv', 3, transform=transforms_train)
Optimal31_trainDataset40 = Dataset_creator('/kaggle/working/Optimal31_train.csv', 4, transform=transforms_train)
Optimal31_testDataset = Dataset_creator('/kaggle/working/Optimal31_test.csv', transform=transforms_test)

# create DataLoader objects for training and testing
Optimal31_trainDatasetLoader = DataLoader(Optimal31_trainDataset, batch_size=32, shuffle=True)
Optimal31_trainDatasetLoader10 = DataLoader(Optimal31_trainDataset10, batch_size=32, shuffle=True)
Optimal31_trainDatasetLoader20 = DataLoader(Optimal31_trainDataset20, batch_size=32, shuffle=True)
Optimal31_trainDatasetLoader40= DataLoader(Optimal31_trainDataset40, batch_size=32, shuffle=True)
Optimal31_testDatasetLoader = DataLoader(Optimal31_testDataset, batch_size=32, shuffle=False)

# %%
UCM_dataloaders = [(UCM_trainDatasetLoader,UCM_testDatasetLoader), (UCM_trainDatasetLoader10,UCM_testDatasetLoader),
                  (UCM_trainDatasetLoader20,UCM_testDatasetLoader), (UCM_trainDatasetLoader40,UCM_testDatasetLoader)]

Optimal31_dataloaders = [(Optimal31_trainDatasetLoader,Optimal31_testDatasetLoader), (Optimal31_trainDatasetLoader10,Optimal31_testDatasetLoader),
                        (Optimal31_trainDatasetLoader20,Optimal31_testDatasetLoader), (Optimal31_trainDatasetLoader40,Optimal31_testDatasetLoader)]

noise_percent = [0, 10, 20, 40]

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
from timeit import default_timer as timer 
def print_train_time(start: float, end: float, device: torch.device = None):
    """Prints difference between start and end time.

    Args:
        start (float): Start time of computation (preferred in timeit format). 
        end (float): End time of computation.
        device ([type], optional): Device that compute is running on. Defaults to None.

    Returns:
        float: time between start and end in seconds (higher is longer).
    """
    total_time = end - start
    print(f"Train time on {device}: {total_time:.3f} seconds")
    return total_time

def accuracy_fn(y_true, y_pred):
  correct = torch.eq(y_true, y_pred).sum().item()
  acc = (correct/len(y_pred))*100
  return acc

# %%
def train_step(model: torch.nn.Module,
               data_loader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               accuracy_fn,
               device: torch.device = device):

    train_loss, train_acc = 0, 0
    for batch, (X, y) in enumerate(data_loader):
        # Send data to GPU
        X, y = X.to(device), y.to(device)
        
        # Optimizer zero grad
        optimizer.zero_grad()

        # Forward pass
        y_pred = model(X)

        # Calculate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()
        train_acc += accuracy_fn(y_true=y,
                                 y_pred=y_pred.argmax(dim=1)) # Go from logits -> pred labels

        # Loss backward
        loss.backward()

        # Optimizer step
        optimizer.step()
        
        # Free up GPU memory
        del X, y, y_pred, loss
        torch.cuda.empty_cache()

    # Calculate loss and accuracy per epoch and print out what's happening
    train_loss /= len(data_loader)
    train_acc /= len(data_loader)
    print(f"Train loss: {train_loss:.5f} | Train accuracy: {train_acc:.2f}%")
    return train_loss, train_acc

def test_step(data_loader: torch.utils.data.DataLoader,
              model: torch.nn.Module,
              loss_fn: torch.nn.Module,
              accuracy_fn,
              device: torch.device = device):
    


    test_loss, test_acc = 0, 0
    model.eval() # put model in eval mode
    # Turn on inference context manager
    with torch.inference_mode(): 
        for X, y in data_loader:
            # Send data to GPU
            X, y = X.to(device), y.to(device)
            
            # 1. Forward pass
            test_pred = model(X)
            
            # 2. Calculate loss and accuracy
            test_loss += loss_fn(test_pred, y).item()
            test_acc += accuracy_fn(y_true=y,
                y_pred=test_pred.argmax(dim=1) # Go from logits -> pred labels
            )
            # Free up GPU memory
            del X, y, test_pred
            torch.cuda.empty_cache()
        
        # Adjust metrics and print out
        test_loss /= len(data_loader)
        test_acc /= len(data_loader)
        print(f"Test loss: {test_loss:.5f} | Test accuracy: {test_acc:.2f}%\n")
        return test_loss, test_acc

# %% [markdown]
# # VIT - UCMerced

# %%
torch.manual_seed(42)
import time

# Measure time
from timeit import default_timer as timer

all_dataset_train_time_VIT = []
all_dataset_train_loss = []
all_dataset_train_acc = []
all_dataset_test_loss = []
all_dataset_test_acc = []

for i, dataloader in enumerate(UCM_dataloaders):
    print(f"Training VIT for UCMerced Dataset with {noise_percent[i]}% noise in Traning samples")
    UCM_VIT = torchvision.models.vit_b_16(weights='DEFAULT')
    UCM_VIT.heads.head = nn.Linear(in_features=768, out_features=len(UCM_classes), bias=True)

    for name, param in UCM_VIT.named_parameters():
        if name=='heads.head.weight' or name=='heads.head.bias':
            param.requires_grad = True
        else:
            param.requires_grad = False
        
    
    train_dataloader, test_dataloader = dataloader[0], dataloader[1]
    model_VIT = UCM_VIT.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model_VIT.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)
    
    # Train and test model 
    epochs = 60
    trainLoss, trainAcc = [], []
    testLoss, testAcc  = [], []

    train_time_start_VIT = timer()

    for epoch in range(epochs):
        print(f"Epoch: {epoch}\n---------")
        tr_l, tr_a = train_step(data_loader=train_dataloader, 
                    model=model_VIT, 
                    loss_fn=criterion,
                    optimizer=optimizer,
                    accuracy_fn=accuracy_fn,
                    device=device
        )
        
        trainLoss.append(tr_l)
        trainAcc.append(tr_a)

        ts_l, ts_a = test_step(data_loader=test_dataloader,
                    model=model_VIT,
                    loss_fn=criterion,
                    accuracy_fn=accuracy_fn,
                    device=device
        )

        testLoss.append(ts_l)
        testAcc.append(ts_a)


    train_time_end_VIT = timer()
    total_train_time_VIT = print_train_time(start=train_time_start_VIT,
                                            end=train_time_end_VIT,
                                            device=device)
    all_dataset_train_time_VIT.append(total_train_time_VIT)
    all_dataset_train_loss.append(trainLoss)
    all_dataset_train_acc.append(trainAcc)
    all_dataset_test_loss.append(testLoss)
    all_dataset_test_acc.append(testAcc)
    print("\n\n")


UCM_VIT_dict = {'Time':all_dataset_train_time_VIT,
                  'trainLoss':all_dataset_train_loss, 
                  'trainAcc':all_dataset_train_acc, 
                  'testLoss':all_dataset_test_loss, 
                  'testAcc':all_dataset_test_acc}

joblib.dump(UCM_VIT_dict, 'UCM_VIT_dict')
# Out:
# Training VIT for UCMerced Dataset with 0% noise in Traning samples
# Downloading: "https://download.pytorch.org/models/vit_b_16-c867db91.pth" to /root/.cache/torch/hub/checkpoints/vit_b_16-c867db91.pth
#   0%|          | 0.00/330M [00:00<?, ?B/s]
# Epoch: 0
# ---------
# Train loss: 2.49390 | Train accuracy: 35.02%
# Test loss: 1.70448 | Test accuracy: 71.43%
#
# Epoch: 1
# ---------
# Train loss: 1.28770 | Train accuracy: 83.20%
# Test loss: 1.05215 | Test accuracy: 86.38%
#
# Epoch: 2
# ---------
# Train loss: 0.82543 | Train accuracy: 91.39%
# Test loss: 0.77939 | Test accuracy: 89.96%
#
# Epoch: 3
# ---------
# Train loss: 0.61328 | Train accuracy: 93.57%
# Test loss: 0.63973 | Test accuracy: 90.18%
#
# Epoch: 4
# ---------
# Train loss: 0.49223 | Train accuracy: 94.87%
# Test loss: 0.55037 | Test accuracy: 91.96%
#
# Epoch: 5
# ---------
# Train loss: 0.41344 | Train accuracy: 95.11%
# Test loss: 0.49235 | Test accuracy: 92.63%
#
# Epoch: 6
# ---------
# Train loss: 0.35886 | Train accuracy: 96.11%
# Test loss: 0.45113 | Test accuracy: 92.41%
#
# Epoch: 7
# ---------
# Train loss: 0.31992 | Train accuracy: 96.29%
# Test loss: 0.41624 | Test accuracy: 93.53%
#
# Epoch: 8
# ---------
# Train loss: 0.28751 | Train accuracy: 96.82%
# Test loss: 0.38880 | Test accuracy: 93.75%
#
# Epoch: 9
# ---------
# Train loss: 0.26195 | Train accuracy: 97.11%
# Test loss: 0.36961 | Test accuracy: 93.97%
#
# Epoch: 10
# ---------
# Train loss: 0.24184 | Train accuracy: 97.52%
# Test loss: 0.35082 | Test accuracy: 94.42%
#
# Epoch: 11
# ---------
# Train loss: 0.22480 | Train accuracy: 97.76%
# Test loss: 0.33631 | Test accuracy: 94.42%
#
# Epoch: 12
# ---------
# Train loss: 0.20804 | Train accuracy: 97.64%
# Test loss: 0.32255 | Test accuracy: 94.64%
#
# Epoch: 13
# ---------
# Train loss: 0.19814 | Train accuracy: 98.23%
# Test loss: 0.31200 | Test accuracy: 94.64%
#
# Epoch: 14
# ---------
# Train loss: 0.18462 | Train accuracy: 98.41%
# Test loss: 0.30080 | Test accuracy: 94.87%
#
# Epoch: 15
# ---------
# Train loss: 0.17537 | Train accuracy: 98.53%
# Test loss: 0.29263 | Test accuracy: 94.87%
#
# Epoch: 16
# ---------
# Train loss: 0.16433 | Train accuracy: 98.70%
# Test loss: 0.28443 | Test accuracy: 95.31%
#
# Epoch: 17
# ---------
# Train loss: 0.15863 | Train accuracy: 98.64%
# Test loss: 0.27746 | Test accuracy: 95.09%
#
# Epoch: 18
# ---------
# Train loss: 0.14900 | Train accuracy: 98.70%
# Test loss: 0.27155 | Test accuracy: 95.31%
#
# Epoch: 19
# ---------
# Train loss: 0.14248 | Train accuracy: 98.88%
# Test loss: 0.26578 | Test accuracy: 95.54%
#
# Epoch: 20
# ---------
# Train loss: 0.13726 | Train accuracy: 99.00%
# Test loss: 0.26060 | Test accuracy: 95.76%
#
# Epoch: 21
# ---------
# Train loss: 0.13095 | Train accuracy: 99.12%
# Test loss: 0.25566 | Test accuracy: 95.54%
#
# Epoch: 22
# ---------
# Train loss: 0.12773 | Train accuracy: 99.17%
# Test loss: 0.25056 | Test accuracy: 95.76%
#
# Epoch: 23
# ---------
# Train loss: 0.12238 | Train accuracy: 99.17%
# Test loss: 0.24579 | Test accuracy: 95.76%
#
# Epoch: 24
# ---------
# Train loss: 0.11851 | Train accuracy: 99.17%
# Test loss: 0.24252 | Test accuracy: 95.76%
#
# Epoch: 25
# ---------
# Train loss: 0.11380 | Train accuracy: 99.47%
# Test loss: 0.23908 | Test accuracy: 95.76%
#
# Epoch: 26
# ---------
# Train loss: 0.10892 | Train accuracy: 99.35%
# Test loss: 0.23548 | Test accuracy: 95.76%
#
# Epoch: 27
# ---------
# Train loss: 0.10570 | Train accuracy: 99.53%
# Test loss: 0.23272 | Test accuracy: 95.54%
#
# Epoch: 28
# ---------
# Train loss: 0.10403 | Train accuracy: 99.53%
# Test loss: 0.22941 | Test accuracy: 95.76%
#
# Epoch: 29
# ---------
# Train loss: 0.09910 | Train accuracy: 99.53%
# Test loss: 0.22564 | Test accuracy: 95.76%
#
# Epoch: 30
# ---------
# Train loss: 0.09733 | Train accuracy: 99.53%
# Test loss: 0.22391 | Test accuracy: 95.76%
#
# Epoch: 31
# ---------
# Train loss: 0.09378 | Train accuracy: 99.59%
# Test loss: 0.22111 | Test accuracy: 95.98%
#
# Epoch: 32
# ---------
# Train loss: 0.09196 | Train accuracy: 99.65%
# Test loss: 0.21889 | Test accuracy: 95.98%
#
# Epoch: 33
# ---------
# Train loss: 0.08894 | Train accuracy: 99.65%
# Test loss: 0.21670 | Test accuracy: 95.98%
#
# Epoch: 34
# ---------
# Train loss: 0.08606 | Train accuracy: 99.71%
# Test loss: 0.21472 | Test accuracy: 95.98%
#
# Epoch: 35
# ---------
# Train loss: 0.08542 | Train accuracy: 99.71%
# Test loss: 0.21216 | Test accuracy: 95.98%
#
# Epoch: 36
# ---------
# Train loss: 0.08288 | Train accuracy: 99.82%
# Test loss: 0.21069 | Test accuracy: 95.98%
#
# Epoch: 37
# ---------
# Train loss: 0.07986 | Train accuracy: 99.82%
# Test loss: 0.20833 | Test accuracy: 95.98%
#
# Epoch: 38
# ---------
# Train loss: 0.07862 | Train accuracy: 99.71%
# Test loss: 0.20743 | Test accuracy: 95.98%
#
# Epoch: 39
# ---------
# Train loss: 0.07618 | Train accuracy: 99.76%
# Test loss: 0.20467 | Test accuracy: 95.98%
#
# Epoch: 40
# ---------
# Train loss: 0.07427 | Train accuracy: 99.88%
# Test loss: 0.20315 | Test accuracy: 95.98%
#
# Epoch: 41
# ---------
# Train loss: 0.07253 | Train accuracy: 99.88%
# Test loss: 0.20111 | Test accuracy: 95.98%
#
# Epoch: 42
# ---------
# Train loss: 0.07101 | Train accuracy: 99.82%
# Test loss: 0.20040 | Test accuracy: 95.98%
#
# Epoch: 43
# ---------
# Train loss: 0.06984 | Train accuracy: 99.88%
# Test loss: 0.19874 | Test accuracy: 95.98%
#
# Epoch: 44
# ---------
# Train loss: 0.06814 | Train accuracy: 99.88%
# Test loss: 0.19783 | Test accuracy: 95.98%
#
# Epoch: 45
# ---------
# Train loss: 0.06701 | Train accuracy: 99.88%
# Test loss: 0.19654 | Test accuracy: 95.98%
#
# Epoch: 46
# ---------
# Train loss: 0.06531 | Train accuracy: 99.88%
# Test loss: 0.19497 | Test accuracy: 95.98%
#
# Epoch: 47
# ---------
# Train loss: 0.06405 | Train accuracy: 99.88%
# Test loss: 0.19399 | Test accuracy: 95.98%
#
# Epoch: 48
# ---------
# Train loss: 0.06319 | Train accuracy: 99.88%
# Test loss: 0.19272 | Test accuracy: 95.98%
#
# Epoch: 49
# ---------
# Train loss: 0.06261 | Train accuracy: 99.88%
# Test loss: 0.19139 | Test accuracy: 95.98%
#
# Epoch: 50
# ---------
# Train loss: 0.06057 | Train accuracy: 99.88%
# Test loss: 0.19072 | Test accuracy: 95.98%
#
# Epoch: 51
# ---------
# Train loss: 0.05906 | Train accuracy: 99.88%
# Test loss: 0.18959 | Test accuracy: 95.98%
#
# Epoch: 52
# ---------
# Train loss: 0.05865 | Train accuracy: 99.88%
# Test loss: 0.18870 | Test accuracy: 95.98%
#
# Epoch: 53
# ---------
# Train loss: 0.05757 | Train accuracy: 99.88%
# Test loss: 0.18776 | Test accuracy: 95.98%
#
# Epoch: 54
# ---------
# Train loss: 0.05669 | Train accuracy: 99.88%
# Test loss: 0.18642 | Test accuracy: 95.98%
#
# Epoch: 55
# ---------
# Train loss: 0.05574 | Train accuracy: 99.88%
# Test loss: 0.18565 | Test accuracy: 95.98%
#
# Epoch: 56
# ---------
# Train loss: 0.05437 | Train accuracy: 99.94%
# Test loss: 0.18478 | Test accuracy: 95.98%
#
# Epoch: 57
# ---------
# Train loss: 0.05351 | Train accuracy: 99.88%
# Test loss: 0.18389 | Test accuracy: 95.98%
#
# Epoch: 58
# ---------
# Train loss: 0.05266 | Train accuracy: 99.88%
# Test loss: 0.18251 | Test accuracy: 95.98%
#
# Epoch: 59
# ---------
# Train loss: 0.05195 | Train accuracy: 99.94%
# Test loss: 0.18215 | Test accuracy: 95.98%
#
# Train time on cuda: 1089.789 seconds
#
#
#
# Training VIT for UCMerced Dataset with 10% noise in Traning samples
# Epoch: 0
# ---------
# Train loss: 2.53869 | Train accuracy: 36.73%
# Test loss: 1.76279 | Test accuracy: 71.21%
#
# Epoch: 1
# ---------
# Train loss: 1.56539 | Train accuracy: 76.00%
# Test loss: 1.13108 | Test accuracy: 82.81%
#
# Epoch: 2
# ---------
# Train loss: 1.19877 | Train accuracy: 82.02%
# Test loss: 0.87175 | Test accuracy: 87.95%
#
# Epoch: 3
# ---------
# Train loss: 1.02980 | Train accuracy: 84.32%
# Test loss: 0.73002 | Test accuracy: 89.51%
#
# Epoch: 4
# ---------
# Train loss: 0.93238 | Train accuracy: 85.44%
# Test loss: 0.64482 | Test accuracy: 90.40%
#
# Epoch: 5
# ---------
# Train loss: 0.87128 | Train accuracy: 86.03%
# Test loss: 0.58979 | Test accuracy: 90.85%
#
# Epoch: 6
# ---------
# Train loss: 0.82183 | Train accuracy: 86.97%
# Test loss: 0.54860 | Test accuracy: 93.08%
#
# Epoch: 7
# ---------
# Train loss: 0.78890 | Train accuracy: 87.32%
# Test loss: 0.51817 | Test accuracy: 93.30%
#
# Epoch: 8
# ---------
# Train loss: 0.75849 | Train accuracy: 87.32%
# Test loss: 0.49563 | Test accuracy: 93.30%
#
# Epoch: 9
# ---------
# Train loss: 0.73141 | Train accuracy: 88.21%
# Test loss: 0.47853 | Test accuracy: 93.97%
#
# Epoch: 10
# ---------
# Train loss: 0.71148 | Train accuracy: 88.33%
# Test loss: 0.46420 | Test accuracy: 93.97%
#
# Epoch: 11
# ---------
# Train loss: 0.67996 | Train accuracy: 88.68%
# Test loss: 0.45253 | Test accuracy: 94.20%
#
# Epoch: 12
# ---------
# Train loss: 0.66343 | Train accuracy: 88.86%
# Test loss: 0.44044 | Test accuracy: 94.20%
#
# Epoch: 13
# ---------
# Train loss: 0.64393 | Train accuracy: 88.97%
# Test loss: 0.43282 | Test accuracy: 94.42%
#
# Epoch: 14
# ---------
# Train loss: 0.63773 | Train accuracy: 88.92%
# Test loss: 0.42320 | Test accuracy: 93.97%
#
# Epoch: 15
# ---------
# Train loss: 0.61691 | Train accuracy: 89.21%
# Test loss: 0.41926 | Test accuracy: 94.64%
#
# Epoch: 16
# ---------
# Train loss: 0.60298 | Train accuracy: 89.27%
# Test loss: 0.41201 | Test accuracy: 94.42%
#
# Epoch: 17
# ---------
# Train loss: 0.58880 | Train accuracy: 89.27%
# Test loss: 0.40795 | Test accuracy: 94.87%
#
# Epoch: 18
# ---------
# Train loss: 0.58142 | Train accuracy: 89.15%
# Test loss: 0.40272 | Test accuracy: 94.42%
#
# Epoch: 19
# ---------
# Train loss: 0.56503 | Train accuracy: 89.50%
# Test loss: 0.39978 | Test accuracy: 94.42%
#
# Epoch: 20
# ---------
# Train loss: 0.55575 | Train accuracy: 89.21%
# Test loss: 0.39803 | Test accuracy: 94.42%
#
# Epoch: 21
# ---------
# Train loss: 0.54476 | Train accuracy: 89.33%
# Test loss: 0.39533 | Test accuracy: 94.42%
#
# Epoch: 22
# ---------
# Train loss: 0.53179 | Train accuracy: 89.45%
# Test loss: 0.39178 | Test accuracy: 94.20%
#
# Epoch: 23
# ---------
# Train loss: 0.52384 | Train accuracy: 89.80%
# Test loss: 0.38981 | Test accuracy: 94.20%
#
# Epoch: 24
# ---------
# Train loss: 0.50928 | Train accuracy: 89.74%
# Test loss: 0.38489 | Test accuracy: 94.42%
#
# Epoch: 25
# ---------
# Train loss: 0.49537 | Train accuracy: 89.74%
# Test loss: 0.38437 | Test accuracy: 94.20%
#
# Epoch: 26
# ---------
# Train loss: 0.48818 | Train accuracy: 89.68%
# Test loss: 0.38286 | Test accuracy: 94.42%
#
# Epoch: 27
# ---------
# Train loss: 0.47993 | Train accuracy: 89.92%
# Test loss: 0.38177 | Test accuracy: 94.64%
#
# Epoch: 28
# ---------
# Train loss: 0.47486 | Train accuracy: 90.09%
# Test loss: 0.37819 | Test accuracy: 94.20%
#
# Epoch: 29
# ---------
# Train loss: 0.46679 | Train accuracy: 90.09%
# Test loss: 0.37654 | Test accuracy: 94.20%
#
# Epoch: 30
# ---------
# Train loss: 0.45842 | Train accuracy: 90.09%
# Test loss: 0.37518 | Test accuracy: 93.97%
#
# Epoch: 31
# ---------
# Train loss: 0.45339 | Train accuracy: 89.98%
# Test loss: 0.37460 | Test accuracy: 93.97%
#
# Epoch: 32
# ---------
# Train loss: 0.44299 | Train accuracy: 90.33%
# Test loss: 0.37451 | Test accuracy: 94.20%
#
# Epoch: 33
# ---------
# Train loss: 0.43517 | Train accuracy: 90.39%
# Test loss: 0.37264 | Test accuracy: 93.97%
#
# Epoch: 34
# ---------
# Train loss: 0.43172 | Train accuracy: 90.39%
# Test loss: 0.37255 | Test accuracy: 93.97%
#
# Epoch: 35
# ---------
# Train loss: 0.42165 | Train accuracy: 90.45%
# Test loss: 0.37043 | Test accuracy: 94.20%
#
# Epoch: 36
# ---------
# Train loss: 0.41666 | Train accuracy: 90.51%
# Test loss: 0.36778 | Test accuracy: 94.20%
#
# Epoch: 37
# ---------
# Train loss: 0.41276 | Train accuracy: 90.21%
# Test loss: 0.36669 | Test accuracy: 94.20%
#
# Epoch: 38
# ---------
# Train loss: 0.39991 | Train accuracy: 90.51%
# Test loss: 0.36938 | Test accuracy: 94.42%
#
# Epoch: 39
# ---------
# Train loss: 0.38998 | Train accuracy: 90.98%
# Test loss: 0.36820 | Test accuracy: 94.20%
#
# Epoch: 40
# ---------
# Train loss: 0.38800 | Train accuracy: 90.68%
# Test loss: 0.36519 | Test accuracy: 94.20%
#
# Epoch: 41
# ---------
# Train loss: 0.37993 | Train accuracy: 90.98%
# Test loss: 0.36445 | Test accuracy: 94.20%
#
# Epoch: 42
# ---------
# Train loss: 0.37374 | Train accuracy: 91.10%
# Test loss: 0.36475 | Test accuracy: 94.20%
#
# Epoch: 43
# ---------
# Train loss: 0.36686 | Train accuracy: 91.21%
# Test loss: 0.36569 | Test accuracy: 94.42%
#
# Epoch: 44
# ---------
# Train loss: 0.36478 | Train accuracy: 91.63%
# Test loss: 0.36180 | Test accuracy: 94.20%
#
# Epoch: 45
# ---------
# Train loss: 0.35879 | Train accuracy: 91.16%
# Test loss: 0.36101 | Test accuracy: 94.20%
#
# Epoch: 46
# ---------
# Train loss: 0.35316 | Train accuracy: 91.51%
# Test loss: 0.36057 | Test accuracy: 93.97%
#
# Epoch: 47
# ---------
# Train loss: 0.34855 | Train accuracy: 91.27%
# Test loss: 0.35781 | Test accuracy: 93.97%
#
# Epoch: 48
# ---------
# Train loss: 0.34098 | Train accuracy: 91.57%
# Test loss: 0.35789 | Test accuracy: 93.97%
#
# Epoch: 49
# ---------
# Train loss: 0.33735 | Train accuracy: 91.80%
# Test loss: 0.35725 | Test accuracy: 93.75%
#
# Epoch: 50
# ---------
# Train loss: 0.33006 | Train accuracy: 91.63%
# Test loss: 0.35582 | Test accuracy: 93.75%
#
# Epoch: 51
# ---------
# Train loss: 0.32784 | Train accuracy: 92.04%
# Test loss: 0.35548 | Test accuracy: 94.20%
#
# Epoch: 52
# ---------
# Train loss: 0.32316 | Train accuracy: 92.04%
# Test loss: 0.35494 | Test accuracy: 93.97%
#
# Epoch: 53
# ---------
# Train loss: 0.32173 | Train accuracy: 91.92%
# Test loss: 0.35548 | Test accuracy: 93.75%
#
# Epoch: 54
# ---------
# Train loss: 0.31493 | Train accuracy: 92.16%
# Test loss: 0.35440 | Test accuracy: 93.75%
#
# Epoch: 55
# ---------
# Train loss: 0.31152 | Train accuracy: 92.39%
# Test loss: 0.35261 | Test accuracy: 93.97%
#
# Epoch: 56
# ---------
# Train loss: 0.30412 | Train accuracy: 92.33%
# Test loss: 0.35206 | Test accuracy: 93.53%
#
# Epoch: 57
# ---------
# Train loss: 0.30079 | Train accuracy: 92.28%
# Test loss: 0.35208 | Test accuracy: 93.53%
#
# Epoch: 58
# ---------
# Train loss: 0.29818 | Train accuracy: 92.28%
# Test loss: 0.35256 | Test accuracy: 93.75%
#
# Epoch: 59
# ---------
# Train loss: 0.29485 | Train accuracy: 92.63%
# Test loss: 0.35123 | Test accuracy: 93.53%
#
# Train time on cuda: 1090.709 seconds
#
#
#
# Training VIT for UCMerced Dataset with 20% noise in Traning samples
# Epoch: 0
# ---------
# Train loss: 2.66408 | Train accuracy: 29.19%
# Test loss: 1.86336 | Test accuracy: 71.21%
#
# Epoch: 1
# ---------
# Train loss: 1.88728 | Train accuracy: 66.16%
# Test loss: 1.25871 | Test accuracy: 84.38%
#
# Epoch: 2
# ---------
# Train loss: 1.57417 | Train accuracy: 73.00%
# Test loss: 0.99566 | Test accuracy: 88.39%
#
# Epoch: 3
# ---------
# Train loss: 1.43413 | Train accuracy: 75.71%
# Test loss: 0.85812 | Test accuracy: 89.51%
#
# Epoch: 4
# ---------
# Train loss: 1.34205 | Train accuracy: 76.30%
# Test loss: 0.77934 | Test accuracy: 90.62%
#
# Epoch: 5
# ---------
# Train loss: 1.28114 | Train accuracy: 77.24%
# Test loss: 0.72697 | Test accuracy: 92.63%
#
# Epoch: 6
# ---------
# Train loss: 1.22775 | Train accuracy: 77.65%
# Test loss: 0.68987 | Test accuracy: 92.86%
#
# Epoch: 7
# ---------
# Train loss: 1.18701 | Train accuracy: 78.07%
# Test loss: 0.66497 | Test accuracy: 93.53%
#
# Epoch: 8
# ---------
# Train loss: 1.15473 | Train accuracy: 78.12%
# Test loss: 0.64489 | Test accuracy: 93.75%
#
# Epoch: 9
# ---------
# Train loss: 1.12150 | Train accuracy: 78.48%
# Test loss: 0.62927 | Test accuracy: 93.30%
#
# Epoch: 10
# ---------
# Train loss: 1.09361 | Train accuracy: 78.42%
# Test loss: 0.61434 | Test accuracy: 93.30%
#
# Epoch: 11
# ---------
# Train loss: 1.07133 | Train accuracy: 78.60%
# Test loss: 0.60605 | Test accuracy: 93.75%
#
# Epoch: 12
# ---------
# Train loss: 1.04870 | Train accuracy: 78.89%
# Test loss: 0.59651 | Test accuracy: 93.75%
#
# Epoch: 13
# ---------
# Train loss: 1.02460 | Train accuracy: 79.01%
# Test loss: 0.59361 | Test accuracy: 93.75%
#
# Epoch: 14
# ---------
# Train loss: 0.99748 | Train accuracy: 79.07%
# Test loss: 0.58675 | Test accuracy: 93.75%
#
# Epoch: 15
# ---------
# Train loss: 0.97826 | Train accuracy: 79.36%
# Test loss: 0.57915 | Test accuracy: 93.53%
#
# Epoch: 16
# ---------
# Train loss: 0.95520 | Train accuracy: 79.60%
# Test loss: 0.57343 | Test accuracy: 93.97%
#
# Epoch: 17
# ---------
# Train loss: 0.94260 | Train accuracy: 79.48%
# Test loss: 0.56996 | Test accuracy: 94.20%
#
# Epoch: 18
# ---------
# Train loss: 0.92291 | Train accuracy: 79.78%
# Test loss: 0.56880 | Test accuracy: 93.75%
#
# Epoch: 19
# ---------
# Train loss: 0.90554 | Train accuracy: 79.95%
# Test loss: 0.56167 | Test accuracy: 93.53%
#
# Epoch: 20
# ---------
# Train loss: 0.88833 | Train accuracy: 79.89%
# Test loss: 0.55707 | Test accuracy: 93.97%
#
# Epoch: 21
# ---------
# Train loss: 0.87830 | Train accuracy: 80.13%
# Test loss: 0.55769 | Test accuracy: 93.97%
#
# Epoch: 22
# ---------
# Train loss: 0.85915 | Train accuracy: 80.37%
# Test loss: 0.55724 | Test accuracy: 93.30%
#
# Epoch: 23
# ---------
# Train loss: 0.84424 | Train accuracy: 80.31%
# Test loss: 0.55034 | Test accuracy: 94.20%
#
# Epoch: 24
# ---------
# Train loss: 0.83625 | Train accuracy: 80.54%
# Test loss: 0.54862 | Test accuracy: 93.75%
#
# Epoch: 25
# ---------
# Train loss: 0.81771 | Train accuracy: 80.72%
# Test loss: 0.54938 | Test accuracy: 93.75%
#
# Epoch: 26
# ---------
# Train loss: 0.81458 | Train accuracy: 80.78%
# Test loss: 0.54421 | Test accuracy: 93.97%
#
# Epoch: 27
# ---------
# Train loss: 0.80231 | Train accuracy: 81.01%
# Test loss: 0.54448 | Test accuracy: 93.75%
#
# Epoch: 28
# ---------
# Train loss: 0.78260 | Train accuracy: 81.31%
# Test loss: 0.54341 | Test accuracy: 93.08%
#
# Epoch: 29
# ---------
# Train loss: 0.76844 | Train accuracy: 81.49%
# Test loss: 0.54262 | Test accuracy: 93.08%
#
# Epoch: 30
# ---------
# Train loss: 0.76255 | Train accuracy: 81.49%
# Test loss: 0.53731 | Test accuracy: 93.30%
#
# Epoch: 31
# ---------
# Train loss: 0.75077 | Train accuracy: 81.43%
# Test loss: 0.53306 | Test accuracy: 93.30%
#
# Epoch: 32
# ---------
# Train loss: 0.74096 | Train accuracy: 81.84%
# Test loss: 0.53441 | Test accuracy: 93.08%
#
# Epoch: 33
# ---------
# Train loss: 0.72973 | Train accuracy: 82.25%
# Test loss: 0.53608 | Test accuracy: 92.86%
#
# Epoch: 34
# ---------
# Train loss: 0.71959 | Train accuracy: 82.25%
# Test loss: 0.53478 | Test accuracy: 93.08%
#
# Epoch: 35
# ---------
# Train loss: 0.71103 | Train accuracy: 82.43%
# Test loss: 0.53324 | Test accuracy: 92.63%
#
# Epoch: 36
# ---------
# Train loss: 0.70449 | Train accuracy: 82.49%
# Test loss: 0.53165 | Test accuracy: 92.86%
#
# Epoch: 37
# ---------
# Train loss: 0.68967 | Train accuracy: 82.84%
# Test loss: 0.53224 | Test accuracy: 92.63%
#
# Epoch: 38
# ---------
# Train loss: 0.68361 | Train accuracy: 82.78%
# Test loss: 0.52859 | Test accuracy: 92.63%
#
# Epoch: 39
# ---------
# Train loss: 0.67083 | Train accuracy: 82.67%
# Test loss: 0.53175 | Test accuracy: 92.63%
#
# Epoch: 40
# ---------
# Train loss: 0.66495 | Train accuracy: 82.78%
# Test loss: 0.52637 | Test accuracy: 92.63%
#
# Epoch: 41
# ---------
# Train loss: 0.65611 | Train accuracy: 83.02%
# Test loss: 0.52726 | Test accuracy: 92.41%
#
# Epoch: 42
# ---------
# Train loss: 0.64846 | Train accuracy: 82.96%
# Test loss: 0.52564 | Test accuracy: 92.41%
#
# Epoch: 43
# ---------
# Train loss: 0.63911 | Train accuracy: 83.43%
# Test loss: 0.52750 | Test accuracy: 92.19%
#
# Epoch: 44
# ---------
# Train loss: 0.63398 | Train accuracy: 83.84%
# Test loss: 0.52599 | Test accuracy: 92.86%
#
# Epoch: 45
# ---------
# Train loss: 0.62641 | Train accuracy: 83.79%
# Test loss: 0.52143 | Test accuracy: 92.63%
#
# Epoch: 46
# ---------
# Train loss: 0.61753 | Train accuracy: 83.90%
# Test loss: 0.52100 | Test accuracy: 92.63%
#
# Epoch: 47
# ---------
# Train loss: 0.60491 | Train accuracy: 83.90%
# Test loss: 0.52336 | Test accuracy: 92.63%
#
# Epoch: 48
# ---------
# Train loss: 0.60420 | Train accuracy: 84.14%
# Test loss: 0.52439 | Test accuracy: 92.41%
#
# Epoch: 49
# ---------
# Train loss: 0.59586 | Train accuracy: 84.20%
# Test loss: 0.52126 | Test accuracy: 92.41%
#
# Epoch: 50
# ---------
# Train loss: 0.58509 | Train accuracy: 84.67%
# Test loss: 0.52082 | Test accuracy: 91.96%
#
# Epoch: 51
# ---------
# Train loss: 0.57762 | Train accuracy: 84.79%
# Test loss: 0.52191 | Test accuracy: 91.96%
#
# Epoch: 52
# ---------
# Train loss: 0.57010 | Train accuracy: 84.96%
# Test loss: 0.52148 | Test accuracy: 91.52%
#
# Epoch: 53
# ---------
# Train loss: 0.56622 | Train accuracy: 84.96%
# Test loss: 0.51955 | Test accuracy: 91.52%
#
# Epoch: 54
# ---------
# Train loss: 0.55952 | Train accuracy: 85.08%
# Test loss: 0.51954 | Test accuracy: 91.52%
#
# Epoch: 55
# ---------
# Train loss: 0.55017 | Train accuracy: 85.38%
# Test loss: 0.51888 | Test accuracy: 91.29%
#
# Epoch: 56
# ---------
# Train loss: 0.54825 | Train accuracy: 85.55%
# Test loss: 0.51681 | Test accuracy: 91.96%
#
# Epoch: 57
# ---------
# Train loss: 0.53908 | Train accuracy: 85.97%
# Test loss: 0.52057 | Test accuracy: 91.29%
#
# Epoch: 58
# ---------
# Train loss: 0.53800 | Train accuracy: 85.44%
# Test loss: 0.51764 | Test accuracy: 91.52%
#
# Epoch: 59
# ---------
# Train loss: 0.52370 | Train accuracy: 86.50%
# Test loss: 0.52003 | Test accuracy: 91.29%
#
# Train time on cuda: 1067.858 seconds
#
#
#
# Training VIT for UCMerced Dataset with 40% noise in Traning samples
# Epoch: 0
# ---------
# Train loss: 2.89123 | Train accuracy: 16.98%
# Test loss: 2.19038 | Test accuracy: 56.25%
#
# Epoch: 1
# ---------
# Train loss: 2.39544 | Train accuracy: 43.46%
# Test loss: 1.61904 | Test accuracy: 75.00%
#
# Epoch: 2
# ---------
# Train loss: 2.17240 | Train accuracy: 52.30%
# Test loss: 1.37397 | Test accuracy: 82.14%
#
# Epoch: 3
# ---------
# Train loss: 2.05439 | Train accuracy: 54.83%
# Test loss: 1.23925 | Test accuracy: 84.38%
#
# Epoch: 4
# ---------
# Train loss: 1.97156 | Train accuracy: 56.31%
# Test loss: 1.15820 | Test accuracy: 85.04%
#
# Epoch: 5
# ---------
# Train loss: 1.90872 | Train accuracy: 56.84%
# Test loss: 1.11313 | Test accuracy: 87.05%
#
# Epoch: 6
# ---------
# Train loss: 1.85651 | Train accuracy: 57.72%
# Test loss: 1.08313 | Test accuracy: 85.94%
#
# Epoch: 7
# ---------
# Train loss: 1.80282 | Train accuracy: 58.49%
# Test loss: 1.05712 | Test accuracy: 87.28%
#
# Epoch: 8
# ---------
# Train loss: 1.76894 | Train accuracy: 58.14%
# Test loss: 1.03410 | Test accuracy: 87.72%
#
# Epoch: 9
# ---------
# Train loss: 1.72874 | Train accuracy: 58.79%
# Test loss: 1.03002 | Test accuracy: 87.72%
#
# Epoch: 10
# ---------
# Train loss: 1.69635 | Train accuracy: 58.96%
# Test loss: 1.01778 | Test accuracy: 87.95%
#
# Epoch: 11
# ---------
# Train loss: 1.66458 | Train accuracy: 59.32%
# Test loss: 1.01335 | Test accuracy: 88.17%
#
# Epoch: 12
# ---------
# Train loss: 1.63430 | Train accuracy: 59.61%
# Test loss: 1.01199 | Test accuracy: 87.28%
#
# Epoch: 13
# ---------
# Train loss: 1.60282 | Train accuracy: 60.14%
# Test loss: 1.01149 | Test accuracy: 87.50%
#
# Epoch: 14
# ---------
# Train loss: 1.57446 | Train accuracy: 59.91%
# Test loss: 1.00029 | Test accuracy: 87.95%
#
# Epoch: 15
# ---------
# Train loss: 1.55358 | Train accuracy: 60.26%
# Test loss: 1.00134 | Test accuracy: 87.28%
#
# Epoch: 16
# ---------
# Train loss: 1.52633 | Train accuracy: 60.61%
# Test loss: 0.99519 | Test accuracy: 86.83%
#
# Epoch: 17
# ---------
# Train loss: 1.50302 | Train accuracy: 60.79%
# Test loss: 0.99554 | Test accuracy: 86.61%
#
# Epoch: 18
# ---------
# Train loss: 1.47790 | Train accuracy: 60.91%
# Test loss: 0.99839 | Test accuracy: 86.83%
#
# Epoch: 19
# ---------
# Train loss: 1.46021 | Train accuracy: 61.14%
# Test loss: 0.99382 | Test accuracy: 86.61%
#
# Epoch: 20
# ---------
# Train loss: 1.42974 | Train accuracy: 62.26%
# Test loss: 0.98859 | Test accuracy: 86.38%
#
# Epoch: 21
# ---------
# Train loss: 1.41505 | Train accuracy: 61.85%
# Test loss: 0.99136 | Test accuracy: 85.04%
#
# Epoch: 22
# ---------
# Train loss: 1.39224 | Train accuracy: 62.50%
# Test loss: 0.99681 | Test accuracy: 85.49%
#
# Epoch: 23
# ---------
# Train loss: 1.37448 | Train accuracy: 62.50%
# Test loss: 1.00189 | Test accuracy: 84.60%
#
# Epoch: 24
# ---------
# Train loss: 1.35268 | Train accuracy: 63.15%
# Test loss: 0.99425 | Test accuracy: 84.15%
#
# Epoch: 25
# ---------
# Train loss: 1.34690 | Train accuracy: 63.09%
# Test loss: 0.99356 | Test accuracy: 85.27%
#
# Epoch: 26
# ---------
# Train loss: 1.32463 | Train accuracy: 63.56%
# Test loss: 1.00241 | Test accuracy: 83.93%
#
# Epoch: 27
# ---------
# Train loss: 1.30251 | Train accuracy: 63.38%
# Test loss: 0.99425 | Test accuracy: 84.82%
#
# Epoch: 28
# ---------
# Train loss: 1.28458 | Train accuracy: 63.97%
# Test loss: 0.99583 | Test accuracy: 84.38%
#
# Epoch: 29
# ---------
# Train loss: 1.27376 | Train accuracy: 64.74%
# Test loss: 1.00197 | Test accuracy: 84.60%
#
# Epoch: 30
# ---------
# Train loss: 1.25247 | Train accuracy: 65.04%
# Test loss: 0.99399 | Test accuracy: 84.15%
#
# Epoch: 31
# ---------
# Train loss: 1.24158 | Train accuracy: 65.04%
# Test loss: 0.99596 | Test accuracy: 83.93%
#
# Epoch: 32
# ---------
# Train loss: 1.22309 | Train accuracy: 65.62%
# Test loss: 0.99090 | Test accuracy: 84.15%
#
# Epoch: 33
# ---------
# Train loss: 1.21165 | Train accuracy: 65.57%
# Test loss: 1.00082 | Test accuracy: 83.93%
#
# Epoch: 34
# ---------
# Train loss: 1.19754 | Train accuracy: 66.63%
# Test loss: 0.99727 | Test accuracy: 83.04%
#
# Epoch: 35
# ---------
# Train loss: 1.18445 | Train accuracy: 66.92%
# Test loss: 1.00178 | Test accuracy: 83.26%
#
# Epoch: 36
# ---------
# Train loss: 1.16492 | Train accuracy: 67.10%
# Test loss: 1.00820 | Test accuracy: 83.48%
#
# Epoch: 37
# ---------
# Train loss: 1.16034 | Train accuracy: 67.04%
# Test loss: 1.00264 | Test accuracy: 83.48%
#
# Epoch: 38
# ---------
# Train loss: 1.14692 | Train accuracy: 67.92%
# Test loss: 1.00367 | Test accuracy: 82.14%
#
# Epoch: 39
# ---------
# Train loss: 1.13110 | Train accuracy: 68.04%
# Test loss: 1.01316 | Test accuracy: 82.14%
#
# Epoch: 40
# ---------
# Train loss: 1.11644 | Train accuracy: 68.75%
# Test loss: 1.01691 | Test accuracy: 81.25%
#
# Epoch: 41
# ---------
# Train loss: 1.10589 | Train accuracy: 67.92%
# Test loss: 1.01175 | Test accuracy: 81.92%
#
# Epoch: 42
# ---------
# Train loss: 1.09426 | Train accuracy: 69.10%
# Test loss: 1.01608 | Test accuracy: 81.25%
#
# Epoch: 43
# ---------
# Train loss: 1.08623 | Train accuracy: 69.34%
# Test loss: 1.01444 | Test accuracy: 81.03%
#
# Epoch: 44
# ---------
# Train loss: 1.07359 | Train accuracy: 69.87%
# Test loss: 1.01257 | Test accuracy: 81.03%
#
# Epoch: 45
# ---------
# Train loss: 1.06369 | Train accuracy: 70.46%
# Test loss: 1.01374 | Test accuracy: 81.47%
#
# Epoch: 46
# ---------
# Train loss: 1.04547 | Train accuracy: 70.87%
# Test loss: 1.01239 | Test accuracy: 81.03%
#
# Epoch: 47
# ---------
# Train loss: 1.03781 | Train accuracy: 71.11%
# Test loss: 1.01643 | Test accuracy: 80.58%
#
# Epoch: 48
# ---------
# Train loss: 1.03458 | Train accuracy: 71.05%
# Test loss: 1.01862 | Test accuracy: 79.02%
#
# Epoch: 49
# ---------
# Train loss: 1.01497 | Train accuracy: 71.46%
# Test loss: 1.02247 | Test accuracy: 78.79%
#
# Epoch: 50
# ---------
# Train loss: 1.00490 | Train accuracy: 71.93%
# Test loss: 1.01672 | Test accuracy: 80.58%
#
# Epoch: 51
# ---------
# Train loss: 1.00012 | Train accuracy: 71.82%
# Test loss: 1.01555 | Test accuracy: 78.35%
#
# Epoch: 52
# ---------
# Train loss: 0.98777 | Train accuracy: 72.17%
# Test loss: 1.02937 | Test accuracy: 78.12%
#
# Epoch: 53
# ---------
# Train loss: 0.97704 | Train accuracy: 72.94%
# Test loss: 1.02591 | Test accuracy: 78.12%
#
# Epoch: 54
# ---------
# Train loss: 0.96820 | Train accuracy: 73.41%
# Test loss: 1.02439 | Test accuracy: 78.35%
#
# Epoch: 55
# ---------
# Train loss: 0.95975 | Train accuracy: 73.82%
# Test loss: 1.02690 | Test accuracy: 77.46%
#
# Epoch: 56
# ---------
# Train loss: 0.95446 | Train accuracy: 73.70%
# Test loss: 1.03175 | Test accuracy: 77.68%
#
# Epoch: 57
# ---------
# Train loss: 0.94096 | Train accuracy: 74.23%
# Test loss: 1.02832 | Test accuracy: 77.23%
#
# Epoch: 58
# ---------
# Train loss: 0.93492 | Train accuracy: 74.41%
# Test loss: 1.03222 | Test accuracy: 76.56%
#
# Epoch: 59
# ---------
# Train loss: 0.92398 | Train accuracy: 75.24%
# Test loss: 1.03119 | Test accuracy: 77.68%
#
# Train time on cuda: 1070.476 seconds
# ['UCM_VIT_dict']

# %% [markdown]
# # VIT - Optimal-31

# %%
torch.manual_seed(42)
import time

# Measure time
from timeit import default_timer as timer

all_dataset_train_time_VIT = []
all_dataset_train_loss = []
all_dataset_train_acc = []
all_dataset_test_loss = []
all_dataset_test_acc = []

for i, dataloader in enumerate(Optimal31_dataloaders):
    print(f"Training VIT for Optimal-31 Dataset with {noise_percent[i]}% noise in Traning samples")
    Optimal31_VIT = torchvision.models.vit_b_16(weights='DEFAULT')
    Optimal31_VIT.heads.head = nn.Linear(in_features=768, out_features=len(Optimal31_classes), bias=True)
    
    for name, param in Optimal31_VIT.named_parameters():
        if name=='heads.head.weight' or name=='heads.head.bias':
            param.requires_grad = True
        else:
            param.requires_grad = False    
    
    train_dataloader, test_dataloader = dataloader[0], dataloader[1]
    model_VIT = Optimal31_VIT.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model_VIT.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)
    
    # Train and test model 
    epochs = 60
    trainLoss, trainAcc = [], []
    testLoss, testAcc  = [], []

    train_time_start_VIT = timer()

    for epoch in range(epochs):
        print(f"Epoch: {epoch}\n---------")
        tr_l, tr_a = train_step(data_loader=train_dataloader, 
                    model=model_VIT, 
                    loss_fn=criterion,
                    optimizer=optimizer,
                    accuracy_fn=accuracy_fn,
                    device=device
        )
        
        trainLoss.append(tr_l)
        trainAcc.append(tr_a)

        ts_l, ts_a = test_step(data_loader=test_dataloader,
                    model=model_VIT,
                    loss_fn=criterion,
                    accuracy_fn=accuracy_fn,
                    device=device
        )

        testLoss.append(ts_l)
        testAcc.append(ts_a)


    train_time_end_VIT = timer()
    total_train_time_VIT = print_train_time(start=train_time_start_VIT,
                                            end=train_time_end_VIT,
                                            device=device)
    all_dataset_train_time_VIT.append(total_train_time_VIT)
    all_dataset_train_loss.append(trainLoss)
    all_dataset_train_acc.append(trainAcc)
    all_dataset_test_loss.append(testLoss)
    all_dataset_test_acc.append(testAcc)
    print("\n\n")


Optimal31_VIT_dict = {'Time':all_dataset_train_time_VIT,
                  'trainLoss':all_dataset_train_loss, 
                  'trainAcc':all_dataset_train_acc, 
                  'testLoss':all_dataset_test_loss, 
                  'testAcc':all_dataset_test_acc}

joblib.dump(Optimal31_VIT_dict, 'Optimal31_VIT_dict')
# Out:
# Training VIT for Optimal-31 Dataset with 0% noise in Traning samples
# Epoch: 0
# ---------
# Train loss: 3.12458 | Train accuracy: 19.81%
# Test loss: 2.67946 | Test accuracy: 41.25%
#
# Epoch: 1
# ---------
# Train loss: 2.21743 | Train accuracy: 62.50%
# Test loss: 1.99157 | Test accuracy: 64.69%
#
# Epoch: 2
# ---------
# Train loss: 1.63966 | Train accuracy: 76.93%
# Test loss: 1.57625 | Test accuracy: 71.46%
#
# Epoch: 3
# ---------
# Train loss: 1.28996 | Train accuracy: 82.65%
# Test loss: 1.32489 | Test accuracy: 75.68%
#
# Epoch: 4
# ---------
# Train loss: 1.07149 | Train accuracy: 85.57%
# Test loss: 1.16351 | Test accuracy: 78.28%
#
# Epoch: 5
# ---------
# Train loss: 0.92511 | Train accuracy: 87.03%
# Test loss: 1.04777 | Test accuracy: 80.10%
#
# Epoch: 6
# ---------
# Train loss: 0.81555 | Train accuracy: 88.36%
# Test loss: 0.96134 | Test accuracy: 79.95%
#
# Epoch: 7
# ---------
# Train loss: 0.73272 | Train accuracy: 89.23%
# Test loss: 0.89977 | Test accuracy: 79.53%
#
# Epoch: 8
# ---------
# Train loss: 0.66476 | Train accuracy: 90.36%
# Test loss: 0.84769 | Test accuracy: 81.35%
#
# Epoch: 9
# ---------
# Train loss: 0.61427 | Train accuracy: 90.96%
# Test loss: 0.80810 | Test accuracy: 81.61%
#
# Epoch: 10
# ---------
# Train loss: 0.56943 | Train accuracy: 91.89%
# Test loss: 0.77233 | Test accuracy: 82.40%
#
# Epoch: 11
# ---------
# Train loss: 0.53180 | Train accuracy: 92.15%
# Test loss: 0.74398 | Test accuracy: 81.61%
#
# Epoch: 12
# ---------
# Train loss: 0.49854 | Train accuracy: 93.15%
# Test loss: 0.71808 | Test accuracy: 83.75%
#
# Epoch: 13
# ---------
# Train loss: 0.47363 | Train accuracy: 92.35%
# Test loss: 0.69585 | Test accuracy: 82.71%
#
# Epoch: 14
# ---------
# Train loss: 0.44119 | Train accuracy: 93.82%
# Test loss: 0.67512 | Test accuracy: 83.23%
#
# Epoch: 15
# ---------
# Train loss: 0.42010 | Train accuracy: 94.35%
# Test loss: 0.65908 | Test accuracy: 83.75%
#
# Epoch: 16
# ---------
# Train loss: 0.40196 | Train accuracy: 94.61%
# Test loss: 0.64523 | Test accuracy: 84.17%
#
# Epoch: 17
# ---------
# Train loss: 0.37967 | Train accuracy: 95.01%
# Test loss: 0.63011 | Test accuracy: 84.69%
#
# Epoch: 18
# ---------
# Train loss: 0.36319 | Train accuracy: 95.55%
# Test loss: 0.61781 | Test accuracy: 84.43%
#
# Epoch: 19
# ---------
# Train loss: 0.34702 | Train accuracy: 95.88%
# Test loss: 0.60695 | Test accuracy: 84.95%
#
# Epoch: 20
# ---------
# Train loss: 0.33831 | Train accuracy: 95.94%
# Test loss: 0.59934 | Test accuracy: 85.21%
#
# Epoch: 21
# ---------
# Train loss: 0.32223 | Train accuracy: 96.41%
# Test loss: 0.58701 | Test accuracy: 85.21%
#
# Epoch: 22
# ---------
# Train loss: 0.31027 | Train accuracy: 96.41%
# Test loss: 0.57898 | Test accuracy: 85.47%
#
# Epoch: 23
# ---------
# Train loss: 0.30060 | Train accuracy: 96.34%
# Test loss: 0.57085 | Test accuracy: 85.21%
#
# Epoch: 24
# ---------
# Train loss: 0.28993 | Train accuracy: 97.07%
# Test loss: 0.56469 | Test accuracy: 85.21%
#
# Epoch: 25
# ---------
# Train loss: 0.27695 | Train accuracy: 97.27%
# Test loss: 0.55735 | Test accuracy: 85.47%
#
# Epoch: 26
# ---------
# Train loss: 0.26989 | Train accuracy: 97.01%
# Test loss: 0.55015 | Test accuracy: 85.73%
#
# Epoch: 27
# ---------
# Train loss: 0.25998 | Train accuracy: 97.34%
# Test loss: 0.54435 | Test accuracy: 85.99%
#
# Epoch: 28
# ---------
# Train loss: 0.25236 | Train accuracy: 97.41%
# Test loss: 0.53783 | Test accuracy: 86.25%
#
# Epoch: 29
# ---------
# Train loss: 0.24603 | Train accuracy: 97.54%
# Test loss: 0.53440 | Test accuracy: 86.25%
#
# Epoch: 30
# ---------
# Train loss: 0.23651 | Train accuracy: 97.94%
# Test loss: 0.52823 | Test accuracy: 86.25%
#
# Epoch: 31
# ---------
# Train loss: 0.23153 | Train accuracy: 97.87%
# Test loss: 0.52382 | Test accuracy: 86.25%
#
# Epoch: 32
# ---------
# Train loss: 0.22690 | Train accuracy: 98.14%
# Test loss: 0.51885 | Test accuracy: 86.25%
#
# Epoch: 33
# ---------
# Train loss: 0.22074 | Train accuracy: 98.07%
# Test loss: 0.51752 | Test accuracy: 85.99%
#
# Epoch: 34
# ---------
# Train loss: 0.21346 | Train accuracy: 98.40%
# Test loss: 0.51226 | Test accuracy: 86.51%
#
# Epoch: 35
# ---------
# Train loss: 0.20723 | Train accuracy: 98.60%
# Test loss: 0.50833 | Test accuracy: 86.25%
#
# Epoch: 36
# ---------
# Train loss: 0.20320 | Train accuracy: 98.67%
# Test loss: 0.50377 | Test accuracy: 86.25%
#
# Epoch: 37
# ---------
# Train loss: 0.19930 | Train accuracy: 98.74%
# Test loss: 0.50044 | Test accuracy: 86.51%
#
# Epoch: 38
# ---------
# Train loss: 0.19215 | Train accuracy: 98.87%
# Test loss: 0.49647 | Test accuracy: 86.25%
#
# Epoch: 39
# ---------
# Train loss: 0.18993 | Train accuracy: 98.80%
# Test loss: 0.49504 | Test accuracy: 85.99%
#
# Epoch: 40
# ---------
# Train loss: 0.18645 | Train accuracy: 98.94%
# Test loss: 0.49207 | Test accuracy: 86.25%
#
# Epoch: 41
# ---------
# Train loss: 0.18037 | Train accuracy: 98.87%
# Test loss: 0.48946 | Test accuracy: 85.99%
#
# Epoch: 42
# ---------
# Train loss: 0.17587 | Train accuracy: 99.07%
# Test loss: 0.48749 | Test accuracy: 85.99%
#
# Epoch: 43
# ---------
# Train loss: 0.17127 | Train accuracy: 99.20%
# Test loss: 0.48478 | Test accuracy: 86.25%
#
# Epoch: 44
# ---------
# Train loss: 0.16967 | Train accuracy: 99.14%
# Test loss: 0.48306 | Test accuracy: 86.51%
#
# Epoch: 45
# ---------
# Train loss: 0.16483 | Train accuracy: 99.27%
# Test loss: 0.47929 | Test accuracy: 86.51%
#
# Epoch: 46
# ---------
# Train loss: 0.16182 | Train accuracy: 99.20%
# Test loss: 0.47723 | Test accuracy: 86.51%
#
# Epoch: 47
# ---------
# Train loss: 0.15986 | Train accuracy: 99.20%
# Test loss: 0.47522 | Test accuracy: 86.77%
#
# Epoch: 48
# ---------
# Train loss: 0.15496 | Train accuracy: 99.34%
# Test loss: 0.47395 | Test accuracy: 86.25%
#
# Epoch: 49
# ---------
# Train loss: 0.15227 | Train accuracy: 99.20%
# Test loss: 0.47174 | Test accuracy: 86.25%
#
# Epoch: 50
# ---------
# Train loss: 0.15057 | Train accuracy: 99.34%
# Test loss: 0.47036 | Test accuracy: 86.25%
#
# Epoch: 51
# ---------
# Train loss: 0.14826 | Train accuracy: 99.27%
# Test loss: 0.46735 | Test accuracy: 86.51%
#
# Epoch: 52
# ---------
# Train loss: 0.14595 | Train accuracy: 99.34%
# Test loss: 0.46596 | Test accuracy: 86.25%
#
# Epoch: 53
# ---------
# Train loss: 0.14340 | Train accuracy: 99.27%
# Test loss: 0.46464 | Test accuracy: 86.25%
#
# Epoch: 54
# ---------
# Train loss: 0.13919 | Train accuracy: 99.47%
# Test loss: 0.46314 | Test accuracy: 86.51%
#
# Epoch: 55
# ---------
# Train loss: 0.13658 | Train accuracy: 99.47%
# Test loss: 0.46161 | Test accuracy: 87.03%
#
# Epoch: 56
# ---------
# Train loss: 0.13538 | Train accuracy: 99.34%
# Test loss: 0.46017 | Test accuracy: 86.77%
#
# Epoch: 57
# ---------
# Train loss: 0.13129 | Train accuracy: 99.47%
# Test loss: 0.45807 | Test accuracy: 86.25%
#
# Epoch: 58
# ---------
# Train loss: 0.12973 | Train accuracy: 99.47%
# Test loss: 0.45831 | Test accuracy: 86.51%
#
# Epoch: 59
# ---------
# Train loss: 0.12917 | Train accuracy: 99.47%
# Test loss: 0.45413 | Test accuracy: 87.03%
#
# Train time on cuda: 974.208 seconds
#
#
#
# Training VIT for Optimal-31 Dataset with 10% noise in Traning samples
# Epoch: 0
# ---------
# Train loss: 3.23654 | Train accuracy: 14.76%
# Test loss: 2.81130 | Test accuracy: 36.56%
#
# Epoch: 1
# ---------
# Train loss: 2.47879 | Train accuracy: 51.53%
# Test loss: 2.16170 | Test accuracy: 57.97%
#
# Epoch: 2
# ---------
# Train loss: 1.98056 | Train accuracy: 66.42%
# Test loss: 1.75275 | Test accuracy: 66.30%
#
# Epoch: 3
# ---------
# Train loss: 1.68255 | Train accuracy: 71.14%
# Test loss: 1.49544 | Test accuracy: 70.21%
#
# Epoch: 4
# ---------
# Train loss: 1.49131 | Train accuracy: 74.60%
# Test loss: 1.32306 | Test accuracy: 72.81%
#
# Epoch: 5
# ---------
# Train loss: 1.35990 | Train accuracy: 77.26%
# Test loss: 1.20464 | Test accuracy: 74.64%
#
# Epoch: 6
# ---------
# Train loss: 1.25315 | Train accuracy: 79.06%
# Test loss: 1.11568 | Test accuracy: 76.51%
#
# Epoch: 7
# ---------
# Train loss: 1.17970 | Train accuracy: 80.39%
# Test loss: 1.04833 | Test accuracy: 77.71%
#
# Epoch: 8
# ---------
# Train loss: 1.11226 | Train accuracy: 81.85%
# Test loss: 0.99520 | Test accuracy: 78.23%
#
# Epoch: 9
# ---------
# Train loss: 1.06970 | Train accuracy: 82.25%
# Test loss: 0.95477 | Test accuracy: 78.49%
#
# Epoch: 10
# ---------
# Train loss: 1.02155 | Train accuracy: 82.31%
# Test loss: 0.92076 | Test accuracy: 79.01%
#
# Epoch: 11
# ---------
# Train loss: 0.97779 | Train accuracy: 83.71%
# Test loss: 0.88660 | Test accuracy: 80.47%
#
# Epoch: 12
# ---------
# Train loss: 0.94797 | Train accuracy: 84.04%
# Test loss: 0.86564 | Test accuracy: 80.21%
#
# Epoch: 13
# ---------
# Train loss: 0.91785 | Train accuracy: 84.77%
# Test loss: 0.84631 | Test accuracy: 79.64%
#
# Epoch: 14
# ---------
# Train loss: 0.88866 | Train accuracy: 85.11%
# Test loss: 0.82906 | Test accuracy: 80.21%
#
# Epoch: 15
# ---------
# Train loss: 0.86463 | Train accuracy: 85.97%
# Test loss: 0.81046 | Test accuracy: 80.47%
#
# Epoch: 16
# ---------
# Train loss: 0.83913 | Train accuracy: 86.04%
# Test loss: 0.80063 | Test accuracy: 80.21%
#
# Epoch: 17
# ---------
# Train loss: 0.81040 | Train accuracy: 86.37%
# Test loss: 0.78497 | Test accuracy: 80.05%
#
# Epoch: 18
# ---------
# Train loss: 0.80392 | Train accuracy: 86.04%
# Test loss: 0.77324 | Test accuracy: 80.31%
#
# Epoch: 19
# ---------
# Train loss: 0.77151 | Train accuracy: 86.64%
# Test loss: 0.76575 | Test accuracy: 80.31%
#
# Epoch: 20
# ---------
# Train loss: 0.75356 | Train accuracy: 86.97%
# Test loss: 0.75821 | Test accuracy: 80.47%
#
# Epoch: 21
# ---------
# Train loss: 0.74142 | Train accuracy: 86.97%
# Test loss: 0.74922 | Test accuracy: 80.73%
#
# Epoch: 22
# ---------
# Train loss: 0.71512 | Train accuracy: 87.57%
# Test loss: 0.74357 | Test accuracy: 80.31%
#
# Epoch: 23
# ---------
# Train loss: 0.70583 | Train accuracy: 87.57%
# Test loss: 0.73478 | Test accuracy: 81.25%
#
# Epoch: 24
# ---------
# Train loss: 0.68805 | Train accuracy: 87.70%
# Test loss: 0.72820 | Test accuracy: 81.09%
#
# Epoch: 25
# ---------
# Train loss: 0.67196 | Train accuracy: 88.10%
# Test loss: 0.72543 | Test accuracy: 81.61%
#
# Epoch: 26
# ---------
# Train loss: 0.66227 | Train accuracy: 87.77%
# Test loss: 0.71832 | Test accuracy: 81.09%
#
# Epoch: 27
# ---------
# Train loss: 0.64151 | Train accuracy: 88.30%
# Test loss: 0.71562 | Test accuracy: 81.88%
#
# Epoch: 28
# ---------
# Train loss: 0.63882 | Train accuracy: 88.03%
# Test loss: 0.71226 | Test accuracy: 82.14%
#
# Epoch: 29
# ---------
# Train loss: 0.61498 | Train accuracy: 88.50%
# Test loss: 0.70930 | Test accuracy: 82.40%
#
# Epoch: 30
# ---------
# Train loss: 0.60583 | Train accuracy: 88.63%
# Test loss: 0.70199 | Test accuracy: 82.40%
#
# Epoch: 31
# ---------
# Train loss: 0.59717 | Train accuracy: 88.90%
# Test loss: 0.70308 | Test accuracy: 82.40%
#
# Epoch: 32
# ---------
# Train loss: 0.59039 | Train accuracy: 88.76%
# Test loss: 0.69935 | Test accuracy: 82.14%
#
# Epoch: 33
# ---------
# Train loss: 0.56906 | Train accuracy: 88.90%
# Test loss: 0.69578 | Test accuracy: 81.88%
#
# Epoch: 34
# ---------
# Train loss: 0.56434 | Train accuracy: 89.03%
# Test loss: 0.69196 | Test accuracy: 82.40%
#
# Epoch: 35
# ---------
# Train loss: 0.54895 | Train accuracy: 89.69%
# Test loss: 0.69211 | Test accuracy: 82.14%
#
# Epoch: 36
# ---------
# Train loss: 0.54575 | Train accuracy: 89.43%
# Test loss: 0.68872 | Test accuracy: 81.88%
#
# Epoch: 37
# ---------
# Train loss: 0.52969 | Train accuracy: 89.89%
# Test loss: 0.68544 | Test accuracy: 81.88%
#
# Epoch: 38
# ---------
# Train loss: 0.51974 | Train accuracy: 89.96%
# Test loss: 0.68343 | Test accuracy: 81.35%
#
# Epoch: 39
# ---------
# Train loss: 0.51188 | Train accuracy: 90.09%
# Test loss: 0.68121 | Test accuracy: 81.61%
#
# Epoch: 40
# ---------
# Train loss: 0.50386 | Train accuracy: 90.03%
# Test loss: 0.68003 | Test accuracy: 81.35%
#
# Epoch: 41
# ---------
# Train loss: 0.49649 | Train accuracy: 90.36%
# Test loss: 0.67824 | Test accuracy: 81.61%
#
# Epoch: 42
# ---------
# Train loss: 0.48557 | Train accuracy: 90.89%
# Test loss: 0.67791 | Test accuracy: 81.61%
#
# Epoch: 43
# ---------
# Train loss: 0.48184 | Train accuracy: 90.69%
# Test loss: 0.67721 | Test accuracy: 81.61%
#
# Epoch: 44
# ---------
# Train loss: 0.46749 | Train accuracy: 90.76%
# Test loss: 0.67554 | Test accuracy: 81.61%
#
# Epoch: 45
# ---------
# Train loss: 0.45968 | Train accuracy: 90.69%
# Test loss: 0.67432 | Test accuracy: 81.61%
#
# Epoch: 46
# ---------
# Train loss: 0.45410 | Train accuracy: 90.82%
# Test loss: 0.67189 | Test accuracy: 81.61%
#
# Epoch: 47
# ---------
# Train loss: 0.45610 | Train accuracy: 90.76%
# Test loss: 0.66991 | Test accuracy: 81.20%
#
# Epoch: 48
# ---------
# Train loss: 0.44319 | Train accuracy: 91.02%
# Test loss: 0.67023 | Test accuracy: 81.20%
#
# Epoch: 49
# ---------
# Train loss: 0.43372 | Train accuracy: 91.29%
# Test loss: 0.66889 | Test accuracy: 81.20%
#
# Epoch: 50
# ---------
# Train loss: 0.42425 | Train accuracy: 91.36%
# Test loss: 0.66920 | Test accuracy: 81.20%
#
# Epoch: 51
# ---------
# Train loss: 0.41995 | Train accuracy: 91.22%
# Test loss: 0.66637 | Test accuracy: 81.20%
#
# Epoch: 52
# ---------
# Train loss: 0.40923 | Train accuracy: 91.76%
# Test loss: 0.66669 | Test accuracy: 80.94%
#
# Epoch: 53
# ---------
# Train loss: 0.40662 | Train accuracy: 91.56%
# Test loss: 0.66578 | Test accuracy: 81.20%
#
# Epoch: 54
# ---------
# Train loss: 0.40209 | Train accuracy: 92.02%
# Test loss: 0.66442 | Test accuracy: 80.68%
#
# Epoch: 55
# ---------
# Train loss: 0.39142 | Train accuracy: 92.29%
# Test loss: 0.66349 | Test accuracy: 81.20%
#
# Epoch: 56
# ---------
# Train loss: 0.38775 | Train accuracy: 92.49%
# Test loss: 0.66277 | Test accuracy: 81.20%
#
# Epoch: 57
# ---------
# Train loss: 0.38332 | Train accuracy: 92.49%
# Test loss: 0.66115 | Test accuracy: 81.20%
#
# Epoch: 58
# ---------
# Train loss: 0.37889 | Train accuracy: 92.22%
# Test loss: 0.66029 | Test accuracy: 81.20%
#
# Epoch: 59
# ---------
# Train loss: 0.37169 | Train accuracy: 92.55%
# Test loss: 0.65981 | Test accuracy: 81.20%
#
# Train time on cuda: 954.816 seconds
#
#
#
# Training VIT for Optimal-31 Dataset with 20% noise in Traning samples
# Epoch: 0
# ---------
# Train loss: 3.30133 | Train accuracy: 11.84%
# Test loss: 2.84709 | Test accuracy: 31.77%
#
# Epoch: 1
# ---------
# Train loss: 2.69587 | Train accuracy: 42.82%
# Test loss: 2.24206 | Test accuracy: 59.27%
#
# Epoch: 2
# ---------
# Train loss: 2.28361 | Train accuracy: 60.24%
# Test loss: 1.85001 | Test accuracy: 68.96%
#
# Epoch: 3
# ---------
# Train loss: 2.01556 | Train accuracy: 64.63%
# Test loss: 1.59482 | Test accuracy: 71.41%
#
# Epoch: 4
# ---------
# Train loss: 1.84676 | Train accuracy: 67.75%
# Test loss: 1.42609 | Test accuracy: 73.39%
#
# Epoch: 5
# ---------
# Train loss: 1.71691 | Train accuracy: 69.22%
# Test loss: 1.30899 | Test accuracy: 77.86%
#
# Epoch: 6
# ---------
# Train loss: 1.62247 | Train accuracy: 70.94%
# Test loss: 1.21978 | Test accuracy: 78.91%
#
# Epoch: 7
# ---------
# Train loss: 1.55770 | Train accuracy: 71.28%
# Test loss: 1.15016 | Test accuracy: 80.21%
#
# Epoch: 8
# ---------
# Train loss: 1.49427 | Train accuracy: 71.94%
# Test loss: 1.10060 | Test accuracy: 80.99%
#
# Epoch: 9
# ---------
# Train loss: 1.45226 | Train accuracy: 72.61%
# Test loss: 1.06215 | Test accuracy: 80.99%
#
# Epoch: 10
# ---------
# Train loss: 1.39945 | Train accuracy: 73.34%
# Test loss: 1.03413 | Test accuracy: 80.99%
#
# Epoch: 11
# ---------
# Train loss: 1.36119 | Train accuracy: 73.94%
# Test loss: 1.00665 | Test accuracy: 81.51%
#
# Epoch: 12
# ---------
# Train loss: 1.32287 | Train accuracy: 74.40%
# Test loss: 0.98212 | Test accuracy: 82.03%
#
# Epoch: 13
# ---------
# Train loss: 1.28472 | Train accuracy: 74.93%
# Test loss: 0.96449 | Test accuracy: 82.71%
#
# Epoch: 14
# ---------
# Train loss: 1.25385 | Train accuracy: 75.80%
# Test loss: 0.94629 | Test accuracy: 82.81%
#
# Epoch: 15
# ---------
# Train loss: 1.22192 | Train accuracy: 75.86%
# Test loss: 0.93169 | Test accuracy: 84.17%
#
# Epoch: 16
# ---------
# Train loss: 1.19554 | Train accuracy: 75.93%
# Test loss: 0.92137 | Test accuracy: 83.75%
#
# Epoch: 17
# ---------
# Train loss: 1.17143 | Train accuracy: 76.53%
# Test loss: 0.91099 | Test accuracy: 83.75%
#
# Epoch: 18
# ---------
# Train loss: 1.14898 | Train accuracy: 76.40%
# Test loss: 0.90156 | Test accuracy: 84.27%
#
# Epoch: 19
# ---------
# Train loss: 1.12386 | Train accuracy: 77.06%
# Test loss: 0.89227 | Test accuracy: 83.75%
#
# Epoch: 20
# ---------
# Train loss: 1.10307 | Train accuracy: 77.33%
# Test loss: 0.88869 | Test accuracy: 83.75%
#
# Epoch: 21
# ---------
# Train loss: 1.07269 | Train accuracy: 77.79%
# Test loss: 0.88112 | Test accuracy: 83.49%
#
# Epoch: 22
# ---------
# Train loss: 1.05183 | Train accuracy: 78.06%
# Test loss: 0.87518 | Test accuracy: 83.49%
#
# Epoch: 23
# ---------
# Train loss: 1.03491 | Train accuracy: 78.26%
# Test loss: 0.87091 | Test accuracy: 83.91%
#
# Epoch: 24
# ---------
# Train loss: 1.01584 | Train accuracy: 78.59%
# Test loss: 0.86756 | Test accuracy: 83.23%
#
# Epoch: 25
# ---------
# Train loss: 0.99640 | Train accuracy: 78.72%
# Test loss: 0.86140 | Test accuracy: 83.23%
#
# Epoch: 26
# ---------
# Train loss: 0.98294 | Train accuracy: 78.46%
# Test loss: 0.85774 | Test accuracy: 83.23%
#
# Epoch: 27
# ---------
# Train loss: 0.95504 | Train accuracy: 79.52%
# Test loss: 0.85760 | Test accuracy: 81.77%
#
# Epoch: 28
# ---------
# Train loss: 0.94419 | Train accuracy: 79.39%
# Test loss: 0.85265 | Test accuracy: 82.71%
#
# Epoch: 29
# ---------
# Train loss: 0.93007 | Train accuracy: 79.65%
# Test loss: 0.84913 | Test accuracy: 82.29%
#
# Epoch: 30
# ---------
# Train loss: 0.91062 | Train accuracy: 79.92%
# Test loss: 0.84762 | Test accuracy: 81.77%
#
# Epoch: 31
# ---------
# Train loss: 0.89892 | Train accuracy: 79.92%
# Test loss: 0.84415 | Test accuracy: 82.03%
#
# Epoch: 32
# ---------
# Train loss: 0.87531 | Train accuracy: 80.05%
# Test loss: 0.84401 | Test accuracy: 82.19%
#
# Epoch: 33
# ---------
# Train loss: 0.86694 | Train accuracy: 80.25%
# Test loss: 0.84056 | Test accuracy: 81.51%
#
# Epoch: 34
# ---------
# Train loss: 0.85366 | Train accuracy: 80.92%
# Test loss: 0.83707 | Test accuracy: 81.93%
#
# Epoch: 35
# ---------
# Train loss: 0.83910 | Train accuracy: 80.52%
# Test loss: 0.83694 | Test accuracy: 82.19%
#
# Epoch: 36
# ---------
# Train loss: 0.82780 | Train accuracy: 80.78%
# Test loss: 0.83525 | Test accuracy: 81.93%
#
# Epoch: 37
# ---------
# Train loss: 0.81208 | Train accuracy: 80.72%
# Test loss: 0.83269 | Test accuracy: 82.45%
#
# Epoch: 38
# ---------
# Train loss: 0.79561 | Train accuracy: 80.98%
# Test loss: 0.83264 | Test accuracy: 81.93%
#
# Epoch: 39
# ---------
# Train loss: 0.78205 | Train accuracy: 81.78%
# Test loss: 0.83194 | Test accuracy: 82.45%
#
# Epoch: 40
# ---------
# Train loss: 0.77588 | Train accuracy: 81.78%
# Test loss: 0.83091 | Test accuracy: 82.19%
#
# Epoch: 41
# ---------
# Train loss: 0.75923 | Train accuracy: 81.85%
# Test loss: 0.82847 | Test accuracy: 82.71%
#
# Epoch: 42
# ---------
# Train loss: 0.74941 | Train accuracy: 82.05%
# Test loss: 0.83031 | Test accuracy: 82.71%
#
# Epoch: 43
# ---------
# Train loss: 0.73705 | Train accuracy: 82.45%
# Test loss: 0.82790 | Test accuracy: 81.67%
#
# Epoch: 44
# ---------
# Train loss: 0.72375 | Train accuracy: 82.71%
# Test loss: 0.82707 | Test accuracy: 82.45%
#
# Epoch: 45
# ---------
# Train loss: 0.71935 | Train accuracy: 82.71%
# Test loss: 0.82396 | Test accuracy: 82.45%
#
# Epoch: 46
# ---------
# Train loss: 0.70506 | Train accuracy: 83.05%
# Test loss: 0.82519 | Test accuracy: 82.45%
#
# Epoch: 47
# ---------
# Train loss: 0.69873 | Train accuracy: 83.31%
# Test loss: 0.82287 | Test accuracy: 81.61%
#
# Epoch: 48
# ---------
# Train loss: 0.68458 | Train accuracy: 83.51%
# Test loss: 0.82360 | Test accuracy: 81.51%
#
# Epoch: 49
# ---------
# Train loss: 0.67693 | Train accuracy: 83.78%
# Test loss: 0.82258 | Test accuracy: 81.25%
#
# Epoch: 50
# ---------
# Train loss: 0.66724 | Train accuracy: 83.91%
# Test loss: 0.82426 | Test accuracy: 82.29%
#
# Epoch: 51
# ---------
# Train loss: 0.65418 | Train accuracy: 84.44%
# Test loss: 0.82499 | Test accuracy: 81.09%
#
# Epoch: 52
# ---------
# Train loss: 0.64494 | Train accuracy: 84.57%
# Test loss: 0.82278 | Test accuracy: 80.68%
#
# Epoch: 53
# ---------
# Train loss: 0.63355 | Train accuracy: 85.17%
# Test loss: 0.82404 | Test accuracy: 81.35%
#
# Epoch: 54
# ---------
# Train loss: 0.62992 | Train accuracy: 84.97%
# Test loss: 0.81940 | Test accuracy: 80.83%
#
# Epoch: 55
# ---------
# Train loss: 0.62112 | Train accuracy: 85.24%
# Test loss: 0.82072 | Test accuracy: 82.03%
#
# Epoch: 56
# ---------
# Train loss: 0.61331 | Train accuracy: 85.37%
# Test loss: 0.82034 | Test accuracy: 80.68%
#
# Epoch: 57
# ---------
# Train loss: 0.59760 | Train accuracy: 85.70%
# Test loss: 0.82022 | Test accuracy: 81.51%
#
# Epoch: 58
# ---------
# Train loss: 0.59840 | Train accuracy: 86.04%
# Test loss: 0.81919 | Test accuracy: 81.61%
#
# Epoch: 59
# ---------
# Train loss: 0.58688 | Train accuracy: 86.24%
# Test loss: 0.81947 | Test accuracy: 81.35%
#
# Train time on cuda: 960.740 seconds
#
#
#
# Training VIT for Optimal-31 Dataset with 40% noise in Traning samples
# Epoch: 0
# ---------
# Train loss: 3.36265 | Train accuracy: 9.11%
# Test loss: 3.01364 | Test accuracy: 24.95%
#
# Epoch: 1
# ---------
# Train loss: 2.98947 | Train accuracy: 29.45%
# Test loss: 2.54987 | Test accuracy: 46.41%
#
# Epoch: 2
# ---------
# Train loss: 2.72606 | Train accuracy: 39.36%
# Test loss: 2.21701 | Test accuracy: 55.68%
#
# Epoch: 3
# ---------
# Train loss: 2.53735 | Train accuracy: 46.68%
# Test loss: 1.99307 | Test accuracy: 59.58%
#
# Epoch: 4
# ---------
# Train loss: 2.41208 | Train accuracy: 49.14%
# Test loss: 1.83583 | Test accuracy: 62.45%
#
# Epoch: 5
# ---------
# Train loss: 2.30960 | Train accuracy: 50.73%
# Test loss: 1.71749 | Test accuracy: 66.82%
#
# Epoch: 6
# ---------
# Train loss: 2.22461 | Train accuracy: 52.59%
# Test loss: 1.62990 | Test accuracy: 69.58%
#
# Epoch: 7
# ---------
# Train loss: 2.16179 | Train accuracy: 53.72%
# Test loss: 1.56223 | Test accuracy: 70.36%
#
# Epoch: 8
# ---------
# Train loss: 2.09660 | Train accuracy: 54.26%
# Test loss: 1.51310 | Test accuracy: 71.41%
#
# Epoch: 9
# ---------
# Train loss: 2.04648 | Train accuracy: 55.12%
# Test loss: 1.47447 | Test accuracy: 72.19%
#
# Epoch: 10
# ---------
# Train loss: 1.99299 | Train accuracy: 56.05%
# Test loss: 1.43715 | Test accuracy: 75.10%
#
# Epoch: 11
# ---------
# Train loss: 1.95170 | Train accuracy: 56.18%
# Test loss: 1.41503 | Test accuracy: 73.75%
#
# Epoch: 12
# ---------
# Train loss: 1.91416 | Train accuracy: 56.72%
# Test loss: 1.39757 | Test accuracy: 75.47%
#
# Epoch: 13
# ---------
# Train loss: 1.86621 | Train accuracy: 57.58%
# Test loss: 1.37834 | Test accuracy: 76.51%
#
# Epoch: 14
# ---------
# Train loss: 1.82763 | Train accuracy: 58.11%
# Test loss: 1.36475 | Test accuracy: 77.29%
#
# Epoch: 15
# ---------
# Train loss: 1.79247 | Train accuracy: 58.38%
# Test loss: 1.35462 | Test accuracy: 77.45%
#
# Epoch: 16
# ---------
# Train loss: 1.76488 | Train accuracy: 58.91%
# Test loss: 1.33871 | Test accuracy: 77.86%
#
# Epoch: 17
# ---------
# Train loss: 1.73473 | Train accuracy: 59.04%
# Test loss: 1.33157 | Test accuracy: 77.45%
#
# Epoch: 18
# ---------
# Train loss: 1.69583 | Train accuracy: 59.38%
# Test loss: 1.33039 | Test accuracy: 79.01%
#
# Epoch: 19
# ---------
# Train loss: 1.66759 | Train accuracy: 59.77%
# Test loss: 1.32020 | Test accuracy: 78.49%
#
# Epoch: 20
# ---------
# Train loss: 1.63814 | Train accuracy: 60.17%
# Test loss: 1.31442 | Test accuracy: 79.01%
#
# Epoch: 21
# ---------
# Train loss: 1.61741 | Train accuracy: 60.51%
# Test loss: 1.30520 | Test accuracy: 78.65%
#
# Epoch: 22
# ---------
# Train loss: 1.59114 | Train accuracy: 61.24%
# Test loss: 1.30643 | Test accuracy: 78.91%
#
# Epoch: 23
# ---------
# Train loss: 1.56320 | Train accuracy: 61.84%
# Test loss: 1.30086 | Test accuracy: 78.80%
#
# Epoch: 24
# ---------
# Train loss: 1.53448 | Train accuracy: 62.03%
# Test loss: 1.29585 | Test accuracy: 79.06%
#
# Epoch: 25
# ---------
# Train loss: 1.51360 | Train accuracy: 62.43%
# Test loss: 1.29645 | Test accuracy: 77.86%
#
# Epoch: 26
# ---------
# Train loss: 1.49350 | Train accuracy: 62.10%
# Test loss: 1.29163 | Test accuracy: 76.30%
#
# Epoch: 27
# ---------
# Train loss: 1.46974 | Train accuracy: 62.50%
# Test loss: 1.29562 | Test accuracy: 76.82%
#
# Epoch: 28
# ---------
# Train loss: 1.44839 | Train accuracy: 63.43%
# Test loss: 1.28765 | Test accuracy: 77.34%
#
# Epoch: 29
# ---------
# Train loss: 1.42354 | Train accuracy: 64.56%
# Test loss: 1.28985 | Test accuracy: 76.30%
#
# Epoch: 30
# ---------
# Train loss: 1.40460 | Train accuracy: 64.83%
# Test loss: 1.29122 | Test accuracy: 76.30%
#
# Epoch: 31
# ---------
# Train loss: 1.38113 | Train accuracy: 64.83%
# Test loss: 1.28717 | Test accuracy: 76.04%
#
# Epoch: 32
# ---------
# Train loss: 1.37051 | Train accuracy: 65.36%
# Test loss: 1.28296 | Test accuracy: 77.24%
#
# Epoch: 33
# ---------
# Train loss: 1.34348 | Train accuracy: 66.62%
# Test loss: 1.28891 | Test accuracy: 76.30%
#
# Epoch: 34
# ---------
# Train loss: 1.33133 | Train accuracy: 66.49%
# Test loss: 1.28057 | Test accuracy: 75.26%
#
# Epoch: 35
# ---------
# Train loss: 1.30810 | Train accuracy: 67.15%
# Test loss: 1.28155 | Test accuracy: 74.84%
#
# Epoch: 36
# ---------
# Train loss: 1.29663 | Train accuracy: 67.35%
# Test loss: 1.27418 | Test accuracy: 75.36%
#
# Epoch: 37
# ---------
# Train loss: 1.27793 | Train accuracy: 67.55%
# Test loss: 1.27998 | Test accuracy: 74.74%
#
# Epoch: 38
# ---------
# Train loss: 1.25934 | Train accuracy: 67.89%
# Test loss: 1.28524 | Test accuracy: 73.02%
#
# Epoch: 39
# ---------
# Train loss: 1.24552 | Train accuracy: 67.89%
# Test loss: 1.27523 | Test accuracy: 72.86%
#
# Epoch: 40
# ---------
# Train loss: 1.22397 | Train accuracy: 68.48%
# Test loss: 1.28094 | Test accuracy: 73.80%
#
# Epoch: 41
# ---------
# Train loss: 1.20184 | Train accuracy: 68.82%
# Test loss: 1.28005 | Test accuracy: 72.60%
#
# Epoch: 42
# ---------
# Train loss: 1.19714 | Train accuracy: 69.41%
# Test loss: 1.28216 | Test accuracy: 72.08%
#
# Epoch: 43
# ---------
# Train loss: 1.18218 | Train accuracy: 69.81%
# Test loss: 1.28055 | Test accuracy: 72.08%
#
# Epoch: 44
# ---------
# Train loss: 1.17000 | Train accuracy: 70.15%
# Test loss: 1.27939 | Test accuracy: 72.60%
#
# Epoch: 45
# ---------
# Train loss: 1.15636 | Train accuracy: 70.55%
# Test loss: 1.28269 | Test accuracy: 71.56%
#
# Epoch: 46
# ---------
# Train loss: 1.13658 | Train accuracy: 71.21%
# Test loss: 1.28591 | Test accuracy: 71.56%
#
# Epoch: 47
# ---------
# Train loss: 1.12314 | Train accuracy: 71.54%
# Test loss: 1.28762 | Test accuracy: 71.30%
#
# Epoch: 48
# ---------
# Train loss: 1.10260 | Train accuracy: 72.81%
# Test loss: 1.28415 | Test accuracy: 71.30%
#
# Epoch: 49
# ---------
# Train loss: 1.09347 | Train accuracy: 73.07%
# Test loss: 1.28440 | Test accuracy: 71.04%
#
# Epoch: 50
# ---------
# Train loss: 1.07809 | Train accuracy: 73.74%
# Test loss: 1.28610 | Test accuracy: 70.78%
#
# Epoch: 51
# ---------
# Train loss: 1.06832 | Train accuracy: 73.87%
# Test loss: 1.28802 | Test accuracy: 70.52%
#
# Epoch: 52
# ---------
# Train loss: 1.05946 | Train accuracy: 73.80%
# Test loss: 1.28279 | Test accuracy: 70.00%
#
# Epoch: 53
# ---------
# Train loss: 1.04662 | Train accuracy: 74.73%
# Test loss: 1.28953 | Test accuracy: 70.52%
#
# Epoch: 54
# ---------
# Train loss: 1.03060 | Train accuracy: 74.87%
# Test loss: 1.28848 | Test accuracy: 70.00%
#
# Epoch: 55
# ---------
# Train loss: 1.02846 | Train accuracy: 75.33%
# Test loss: 1.28462 | Test accuracy: 70.00%
#
# Epoch: 56
# ---------
# Train loss: 1.01133 | Train accuracy: 75.73%
# Test loss: 1.28438 | Test accuracy: 70.26%
#
# Epoch: 57
# ---------
# Train loss: 1.00117 | Train accuracy: 76.40%
# Test loss: 1.29156 | Test accuracy: 70.00%
#
# Epoch: 58
# ---------
# Train loss: 0.98752 | Train accuracy: 76.60%
# Test loss: 1.29005 | Test accuracy: 70.00%
#
# Epoch: 59
# ---------
# Train loss: 0.98160 | Train accuracy: 77.39%
# Test loss: 1.29319 | Test accuracy: 69.48%
#
# Train time on cuda: 957.440 seconds
# ['Optimal31_VIT_dict']

# %%
import joblib

UCM_VIT = joblib.load('/kaggle/working/UCM_VIT_dict')
Optimal31_VIT = joblib.load('/kaggle/working/Optimal31_VIT_dict')

# %%
UCM_VIT_times = UCM_VIT['Time']
UCM_VIT_trainLosses = UCM_VIT['trainLoss']
UCM_VIT_trainAccs = UCM_VIT['trainAcc']
UCM_VIT_testLosses = UCM_VIT['testLoss']
UCM_VIT_testAccs  = UCM_VIT['testAcc']

Optimal31_VIT_times = Optimal31_VIT['Time']
Optimal31_VIT_trainLosses = Optimal31_VIT['trainLoss']
Optimal31_VIT_trainAccs = Optimal31_VIT['trainAcc']
Optimal31_VIT_testLosses = Optimal31_VIT['testLoss']
Optimal31_VIT_testAccs  = Optimal31_VIT['testAcc']

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(nrows=2, ncols=4, figsize=(20, 10))

# modelName = ['VIT', 'ShuffleNet', 'VIT']
sample_errors = ['0% error','10% error','20% error','40% error']
datasetName = ['UCMerced', 'Optimal-31']
modelsTrainAccs = [UCM_VIT_trainAccs, Optimal31_VIT_trainAccs]
modelsTestAccs = [UCM_VIT_testAccs, Optimal31_VIT_testAccs]

for i in range(2):
    for j in range(4):
        axs[i,j].plot(modelsTrainAccs[i][j], label='Train', color='blue')
        axs[i,j].plot(modelsTestAccs[i][j], label='Test', color='green')
        axs[i,j].set_xlabel('Epoch')
        axs[i,j].set_ylabel('Accuracy(%)')
        axs[i,j].set_title(f'{datasetName[i]} : {sample_errors[j]}')
        axs[i,j].grid(axis='y')
        axs[i,j].autoscale(enable=True, axis='Accuracy(%)')
        axs[i,j].legend()

# Call tight_layout to automatically adjust the spacing between subplots
plt.tight_layout()

# Add a title to the entire figure
fig.suptitle('Convergence Plots for VIT-pretrained, all the layers are freezed except the last FC layer')

# Adjust the top margin to make more space for the suptitle
plt.subplots_adjust(top=0.9)

# Show the plot
plt.show()

# %%
from tabulate import tabulate
import numpy as np

trainAccuracy_mat = []
testAccuracy_mat = []

for i in range(2):
    trainTemp = []
    testTemp = []
    for j in range(4):
        trainTemp.append(np.average(modelsTrainAccs[i][j][-4:]))
        testTemp.append(np.average(modelsTestAccs[i][j][-4:]))
    trainAccuracy_mat.append(trainTemp)
    testAccuracy_mat.append(testTemp)

# Define headers for columns and rows
headers = ['0% error','10% error','20% error','40% error']
row_headers = ['UCMerced', 'Optimal-31']

table1 = tabulate(trainAccuracy_mat, headers=headers, showindex=row_headers, tablefmt="fancy_grid")
table2 = tabulate(testAccuracy_mat, headers=headers, showindex=row_headers, tablefmt="fancy_grid")

print("Training accuracies")
print(table1,'\n')
print("Test accuracies")
print(table2)
# Out:
# Training accuracies
# ╒════════════╤════════════╤═════════════╤═════════════╤═════════════╕
# │            │   0% error │   10% error │   20% error │   40% error │
# ╞════════════╪════════════╪═════════════╪═════════════╪═════════════╡
# │ UCMerced   │    99.9116 │     92.3791 │     85.8638 │     74.3956 │
# ├────────────┼────────────┼─────────────┼─────────────┼─────────────┤
# │ Optimal-31 │    99.4348 │     92.4368 │     85.8378 │     76.5293 │
# ╘════════════╧════════════╧═════════════╧═════════════╧═════════════╛
#
# Test accuracies
# ╒════════════╤════════════╤═════════════╤═════════════╤═════════════╕
# │            │   0% error │   10% error │   20% error │   40% error │
# ╞════════════╪════════════╪═════════════╪═════════════╪═════════════╡
# │ UCMerced   │    95.9821 │     93.5826 │     91.5179 │     77.2879 │
# ├────────────┼────────────┼─────────────┼─────────────┼─────────────┤
# │ Optimal-31 │    86.6406 │     81.1979 │     81.2891 │     69.9349 │
# ╘════════════╧════════════╧═════════════╧═════════════╧═════════════╛
